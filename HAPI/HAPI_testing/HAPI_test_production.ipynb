# %%
from hapi_testing import test_hapi
import datetime

SERVER_URL =  "https://vires.services"

print(f"{SERVER_URL} {datetime.datetime.utcnow().isoformat()}\n")

test_hapi(SERVER_URL)
# Out:
# https://vires.services 2022-12-17T10:54:27.218962
#
# CS_OPER_MAG 2010-04-08T17:03:26.254008/2022-03-31T23:59:52.266008
#  - CS_OPER_MAG csv 2010-05-13T18:37:58.254008/2010-05-15T18:37:58.254008 ... 26.9MB 3.29s
#  - CS_OPER_MAG json 2010-05-13T18:37:58.254008/2010-05-15T18:37:58.254008 ... 29.3MB 3.5s
#  - CS_OPER_MAG binary 2010-05-13T18:37:58.254008/2010-05-15T18:37:58.254008 ... 11.9MB 0.609s
#  - CS_OPER_MAG x_binary 2010-05-13T18:37:58.254008/2010-05-15T18:37:58.254008 ... 11.2MB 0.592s
# GF1_OPER_FGM_ACAL_CORR 2018-06-01T00:00:00/2022-10-31T23:59:59
#  - GF1_OPER_FGM_ACAL_CORR csv 2022-03-18T05:56:51/2022-03-18T17:56:51 ... 28.0MB 3.38s
#  - GF1_OPER_FGM_ACAL_CORR json 2022-03-18T05:56:51/2022-03-18T17:56:51 ... 30.5MB 3.53s
#  - GF1_OPER_FGM_ACAL_CORR binary 2022-03-18T05:56:51/2022-03-18T17:56:51 ... 12.4MB 0.86s
#  - GF1_OPER_FGM_ACAL_CORR x_binary 2022-03-18T05:56:51/2022-03-18T17:56:51 ... 11.6MB 0.885s
# GF2_OPER_FGM_ACAL_CORR 2018-06-01T00:00:00/2022-10-31T23:59:59
# ...
