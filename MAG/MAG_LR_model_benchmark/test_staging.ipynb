# %% [markdown]
# ## VirES - magnetic model benchmark - staging server
#
# Assess perfomance of the VirES magnetic model evaluation and other parameters wrt. the plain data rerival.
# Get per sample times.
#
# See also [VirES Python Client](https://github.com/ESA-VirES/VirES-Python-Client)

# %%
from benchmark import get_random_collection, run_benchmark_set, write_record

SERVER_URL = "https://staging.vires.services"
FILENAME = "results/2022-11-14_staging_benchmark.log"

COLLECTIONS = ["SW_OPER_MAGA_LR_1B", "SW_OPER_MAGB_LR_1B", "SW_OPER_MAGC_LR_1B"]

MODELS = [
    "CHAOS-Core",
    "CHAOS-Static80 = 'CHAOS-Static'(max_degree=80)",
    "CHAOS-Static",
    "CHAOS-MMA-Primary",
    "CHAOS-MMA-Secondary",
    "CHAOS-MMA",
    "CHAOS80 = 'CHAOS-Core' + 'CHAOS-Static'(max_degree=80) + 'CHAOS-MMA-Primary' + 'CHAOS-MMA-Secondary'",
    "CHAOS",
    "MIO_SHA_2C-Primary",
    "MIO_SHA_2C-Secondary",
    "MIO_SHA_2C",
]

TEST_CASES = [
    dict(description="plain request"),
    dict(description="plain request (cached)"),
    dict(description="filter: Flags_B != 255", filters=["Flags_B != 255"]),
    dict(description="aux.var.: MLT, QDLat", auxiliaries=["MLT", "QDLat"]),
    *(
        dict(description=f"model: { model.partition('=')[0].strip() }", models=[model])
        for model in MODELS 
    ),
]

N_RUNS = 10

SELECTION_TIMES = [
    "P1D",
    "PT6H",
    "PT1H",
    "PT5M",
]


with open(FILENAME, "a", encoding="utf8") as log_file:
    for selection_time in SELECTION_TIMES:
        for idx in range(N_RUNS):
            print(f"{selection_time} pass #{idx+1}")
            collection = get_random_collection(COLLECTIONS)
            for record in run_benchmark_set(SERVER_URL, collection, selection_time, TEST_CASES):
                write_record(record, log_file)
# Out:
# P1D pass #1
# 86400 1.2s plain request
# 86400 0.975s plain request (cached)
# 86400 0.568s filter: Flags_B != 255
# 86400 0.721s aux.var.: MLT, QDLat
# 86400 4.44s model: CHAOS-Core
# 86400 20.2s model: CHAOS-Static80
# 86400 28.9s model: CHAOS-Static
# 86400 37.6s model: CHAOS-MMA-Primary
# 86400 36.5s model: CHAOS-MMA-Secondary
# 86400 73.8s model: CHAOS-MMA
# 86400 95.7s model: CHAOS80
# 86400 105s model: CHAOS
# 86400 17s model: MIO_SHA_2C-Primary
# 86400 16.8s model: MIO_SHA_2C-Secondary
# 86400 34.6s model: MIO_SHA_2C
# P1D pass #2
# 86400 2.01s plain request
# 86400 0.653s plain request (cached)
# 86400 0.569s filter: Flags_B != 255
# 86400 0.757s aux.var.: MLT, QDLat
# 86400 4.27s model: CHAOS-Core
# 86400 19.3s model: CHAOS-Static80
# 86400 28.3s model: CHAOS-Static
# 86400 37.9s model: CHAOS-MMA-Primary
# 86400 39s model: CHAOS-MMA-Secondary
# 86400 76.3s model: CHAOS-MMA
# 86400 94.6s model: CHAOS80
# 86400 106s model: CHAOS
# 86400 17.1s model: MIO_SHA_2C-Primary
# 86400 17.2s model: MIO_SHA_2C-Secondary
# 86400 34.3s model: MIO_SHA_2C
# P1D pass #3
# 86400 1.12s plain request
# 86400 2.52s plain request (cached)
# 86400 0.562s filter: Flags_B != 255
# 86400 0.747s aux.var.: MLT, QDLat
# 86400 4.83s model: CHAOS-Core
# 86400 26.9s model: CHAOS-Static80
# 86400 45.8s model: CHAOS-Static
# 86400 42.6s model: CHAOS-MMA-Primary
# 86400 38.8s model: CHAOS-MMA-Secondary
# 86400 79.9s model: CHAOS-MMA
# 86400 108s model: CHAOS80
# 86400 110s model: CHAOS
# 86400 18.4s model: MIO_SHA_2C-Primary
# 86400 18.1s model: MIO_SHA_2C-Secondary
# 86400 33.7s model: MIO_SHA_2C
# P1D pass #4
# 86400 2.13s plain request
# 86400 1.14s plain request (cached)
# 86400 0.888s filter: Flags_B != 255
# 86400 1.1s aux.var.: MLT, QDLat
# 86400 4.56s model: CHAOS-Core
# 86400 20.4s model: CHAOS-Static80
# 86400 28.5s model: CHAOS-Static
# 86400 37.1s model: CHAOS-MMA-Primary
# 86400 38.1s model: CHAOS-MMA-Secondary
# 86400 73.4s model: CHAOS-MMA
# 86400 96.4s model: CHAOS80
# 86400 110s model: CHAOS
# 86400 17.4s model: MIO_SHA_2C-Primary
# 86400 17.7s model: MIO_SHA_2C-Secondary
# 86400 33.5s model: MIO_SHA_2C
# P1D pass #5
# 86400 1.23s plain request
# 86400 0.99s plain request (cached)
# 86398 0.716s filter: Flags_B != 255
# 86400 0.851s aux.var.: MLT, QDLat
# 86400 4.45s model: CHAOS-Core
# 86400 19.8s model: CHAOS-Static80
# 86400 29.7s model: CHAOS-Static
# 86400 38.9s model: CHAOS-MMA-Primary
# 86400 37.2s model: CHAOS-MMA-Secondary
# 86400 75.9s model: CHAOS-MMA
# 86400 96.8s model: CHAOS80
# 86400 106s model: CHAOS
# 86400 16.6s model: MIO_SHA_2C-Primary
# 86400 17s model: MIO_SHA_2C-Secondary
# 86400 31.7s model: MIO_SHA_2C
# P1D pass #6
# 86400 1.77s plain request
# 86400 3.73s plain request (cached)
# 86400 0.736s filter: Flags_B != 255
# 86400 1s aux.var.: MLT, QDLat
# 86400 5.19s model: CHAOS-Core
# 86400 19.5s model: CHAOS-Static80
# 86400 28.5s model: CHAOS-Static
# 86400 40s model: CHAOS-MMA-Primary
# 86400 38s model: CHAOS-MMA-Secondary
# 86400 74.2s model: CHAOS-MMA
# 86400 98.8s model: CHAOS80
# 86400 34.9s model: MIO_SHA_2C
# P1D pass #7
# 86400 2.61s plain request
# 86400 0.69s plain request (cached)
# 86400 1.01s filter: Flags_B != 255
# 86400 1.32s aux.var.: MLT, QDLat
# 86400 5.22s model: CHAOS-Core
# 86400 20.9s model: CHAOS-Static80
# 86400 30.4s model: CHAOS-Static
# 86400 40.3s model: CHAOS-MMA-Secondary
# 86400 78.3s model: CHAOS-MMA
# 86400 105s model: CHAOS
# 86400 17.1s model: MIO_SHA_2C-Primary
# 86400 16.8s model: MIO_SHA_2C-Secondary
# 86400 32.6s model: MIO_SHA_2C
# P1D pass #8
# 86400 1.85s plain request
# 86400 0.929s plain request (cached)
# 86400 0.809s filter: Flags_B != 255
# 86400 0.749s aux.var.: MLT, QDLat
# 86400 6.38s model: CHAOS-Core
# 86400 19.4s model: CHAOS-Static80
# 86400 29.3s model: CHAOS-Static
# 86400 37.4s model: CHAOS-MMA-Primary
# 86400 36.9s model: CHAOS-MMA-Secondary
# 86400 98.4s model: CHAOS80
# 86400 108s model: CHAOS
# 86400 17.2s model: MIO_SHA_2C-Primary
# 86400 17.2s model: MIO_SHA_2C-Secondary
# 86400 33.1s model: MIO_SHA_2C
# P1D pass #9
# 86400 1.62s plain request
# 86400 2.62s plain request (cached)
# 86400 0.902s filter: Flags_B != 255
# 86400 1.32s aux.var.: MLT, QDLat
# 86400 4.89s model: CHAOS-Core
# 86400 19.6s model: CHAOS-Static80
# 86400 28.5s model: CHAOS-Static
# 86400 37.8s model: CHAOS-MMA-Primary
# 86400 37.6s model: CHAOS-MMA-Secondary
# 86400 73.8s model: CHAOS-MMA
# 86400 98s model: CHAOS80
# 86400 106s model: CHAOS
# 86400 17s model: MIO_SHA_2C-Primary
# 86400 17s model: MIO_SHA_2C-Secondary
# 86400 33s model: MIO_SHA_2C
# P1D pass #10
# 86400 1.1s plain request
# 86400 0.586s plain request (cached)
# 86400 1.11s filter: Flags_B != 255
# 86400 0.9s aux.var.: MLT, QDLat
# 86400 4.58s model: CHAOS-Core
# 86400 19.6s model: CHAOS-Static80
# 86400 28.8s model: CHAOS-Static
# 86400 36.9s model: CHAOS-MMA-Primary
# 86400 38.9s model: CHAOS-MMA-Secondary
# 86400 81.7s model: CHAOS-MMA
# 86400 106s model: CHAOS80
# 86400 18.1s model: MIO_SHA_2C-Secondary
# 86400 35.1s model: MIO_SHA_2C
# PT6H pass #1
# 21600 1.4s plain request
# 21600 0.602s plain request (cached)
# 21600 0.652s filter: Flags_B != 255
# 21600 0.662s aux.var.: MLT, QDLat
# 21600 1.72s model: CHAOS-Core
# 21600 5.28s model: CHAOS-Static80
# 21600 7.44s model: CHAOS-Static
# 21600 9.59s model: CHAOS-MMA-Primary
# 21600 10.8s model: CHAOS-MMA-Secondary
# 21600 19.3s model: CHAOS-MMA
# 21600 24.5s model: CHAOS80
# 21600 27s model: CHAOS
# 21600 4.71s model: MIO_SHA_2C-Primary
# 21600 4.62s model: MIO_SHA_2C-Secondary
# 21600 8.76s model: MIO_SHA_2C
# PT6H pass #2
# 21600 1.29s plain request
# 21600 0.479s plain request (cached)
# 21600 0.907s filter: Flags_B != 255
# 21600 0.943s aux.var.: MLT, QDLat
# 21600 1.38s model: CHAOS-Core
# 21600 5.27s model: CHAOS-Static80
# 21600 7.86s model: CHAOS-Static
# 21600 9.89s model: CHAOS-MMA-Primary
# 21600 10.6s model: CHAOS-MMA-Secondary
# 21600 19s model: CHAOS-MMA
# 21600 24.4s model: CHAOS80
# 21600 26.8s model: CHAOS
# 21600 4.63s model: MIO_SHA_2C-Primary
# 21600 4.55s model: MIO_SHA_2C-Secondary
# 21600 8.56s model: MIO_SHA_2C
# PT6H pass #3
# 21600 0.621s plain request
# 21600 1.06s plain request (cached)
# 21600 0.98s filter: Flags_B != 255
# 21600 1.13s aux.var.: MLT, QDLat
# 21600 2.05s model: CHAOS-Core
# 21600 5.77s model: CHAOS-Static80
# 21600 7.48s model: CHAOS-Static
# 21600 10.7s model: CHAOS-MMA-Primary
# 21600 9.48s model: CHAOS-MMA-Secondary
# 21600 19.1s model: CHAOS-MMA
# 21600 24.3s model: CHAOS80
# 21600 27s model: CHAOS
# 21600 4.65s model: MIO_SHA_2C-Primary
# 21600 4.54s model: MIO_SHA_2C-Secondary
# 21600 9.12s model: MIO_SHA_2C
# PT6H pass #4
# 21600 0.635s plain request
# 21600 0.518s plain request (cached)
# 21600 0.692s filter: Flags_B != 255
# 21600 1.09s aux.var.: MLT, QDLat
# 21600 1.42s model: CHAOS-Core
# 21600 5.41s model: CHAOS-Static80
# 21600 7.8s model: CHAOS-Static
# 21600 9.93s model: CHAOS-MMA-Primary
# 21600 10.8s model: CHAOS-MMA-Secondary
# 21600 19.3s model: CHAOS-MMA
# 21600 26.9s model: CHAOS80
# 21600 27.7s model: CHAOS
# 21600 4.53s model: MIO_SHA_2C-Primary
# 21600 4.57s model: MIO_SHA_2C-Secondary
# 21600 8.53s model: MIO_SHA_2C
# PT6H pass #5
# 21600 0.924s plain request
# 21600 1.01s plain request (cached)
# 21600 1.18s filter: Flags_B != 255
# 21600 0.991s aux.var.: MLT, QDLat
# 21600 1.41s model: CHAOS-Core
# 21600 5.97s model: CHAOS-Static80
# 21600 8.09s model: CHAOS-Static
# 21600 9.7s model: CHAOS-MMA-Primary
# 21600 9.63s model: CHAOS-MMA-Secondary
# 21600 19.6s model: CHAOS-MMA
# 21600 24.6s model: CHAOS80
# 21600 26.3s model: CHAOS
# 21600 4.69s model: MIO_SHA_2C-Primary
# 21600 5.66s model: MIO_SHA_2C-Secondary
# 21600 8.66s model: MIO_SHA_2C
# PT6H pass #6
# 21600 0.718s plain request
# 21600 1.16s plain request (cached)
# 21600 1.01s filter: Flags_B != 255
# 21600 0.938s aux.var.: MLT, QDLat
# 21600 1.78s model: CHAOS-Core
# 21600 5.18s model: CHAOS-Static80
# 21600 7.4s model: CHAOS-Static
# 21600 10.1s model: CHAOS-MMA-Primary
# 21600 9.57s model: CHAOS-MMA-Secondary
# 21600 18.9s model: CHAOS-MMA
# 21600 24.2s model: CHAOS80
# 21600 26.6s model: CHAOS
# 21600 4.98s model: MIO_SHA_2C-Primary
# 21600 4.66s model: MIO_SHA_2C-Secondary
# 21600 9.44s model: MIO_SHA_2C
# PT6H pass #7
# 21600 0.788s plain request
# 21600 0.46s plain request (cached)
# 21600 0.516s filter: Flags_B != 255
# 21600 0.571s aux.var.: MLT, QDLat
# 21600 1.49s model: CHAOS-Core
# 21600 5.71s model: CHAOS-Static80
# 21600 7.41s model: CHAOS-Static
# 21600 9.82s model: CHAOS-MMA-Primary
# 21600 9.88s model: CHAOS-MMA-Secondary
# 21600 19.9s model: CHAOS-MMA
# 21600 25.1s model: CHAOS80
# 21600 27.3s model: CHAOS
# 21600 5.27s model: MIO_SHA_2C-Primary
# 21600 4.61s model: MIO_SHA_2C-Secondary
# 21600 9.15s model: MIO_SHA_2C
# PT6H pass #8
# 21600 0.754s plain request
# 21600 1.06s plain request (cached)
# 21600 0.389s filter: Flags_B != 255
# 21600 0.521s aux.var.: MLT, QDLat
# 21600 1.47s model: CHAOS-Core
# 21600 5.42s model: CHAOS-Static80
# 21600 7.79s model: CHAOS-Static
# 21600 10s model: CHAOS-MMA-Primary
# 21600 9.85s model: CHAOS-MMA-Secondary
# 21600 19.1s model: CHAOS-MMA
# 21600 25s model: CHAOS80
# 21600 26.8s model: CHAOS
# 21600 4.56s model: MIO_SHA_2C-Primary
# 21600 5.12s model: MIO_SHA_2C-Secondary
# 21600 8.45s model: MIO_SHA_2C
# PT6H pass #9
# 21600 1.41s plain request
# 21600 0.703s plain request (cached)
# 21600 0.631s filter: Flags_B != 255
# 21600 0.455s aux.var.: MLT, QDLat
# 21600 1.44s model: CHAOS-Core
# 21600 5.54s model: CHAOS-Static80
# 21600 7.88s model: CHAOS-Static
# 21600 9.77s model: CHAOS-MMA-Primary
# 21600 10s model: CHAOS-MMA-Secondary
# 21600 18.5s model: CHAOS-MMA
# 21600 24.5s model: CHAOS80
# 21600 26.1s model: CHAOS
# 21600 4.54s model: MIO_SHA_2C-Primary
# 21600 4.48s model: MIO_SHA_2C-Secondary
# 21600 9.58s model: MIO_SHA_2C
# PT6H pass #10
# 21600 0.771s plain request
# 21600 1.16s plain request (cached)
# 21600 0.41s filter: Flags_B != 255
# 21600 1.41s aux.var.: MLT, QDLat
# 21600 2.64s model: CHAOS-Core
# 21600 5.26s model: CHAOS-Static80
# 21600 8.41s model: CHAOS-Static
# 21600 9.54s model: CHAOS-MMA-Primary
# 21600 9.52s model: CHAOS-MMA-Secondary
# 21600 18.7s model: CHAOS-MMA
# 21600 24.4s model: CHAOS80
# 21600 26.1s model: CHAOS
# 21600 4.63s model: MIO_SHA_2C-Primary
# 21600 4.69s model: MIO_SHA_2C-Secondary
# 21600 9.46s model: MIO_SHA_2C
# PT1H pass #1
# 3600 0.618s plain request
# 3600 0.323s plain request (cached)
# 3600 0.434s filter: Flags_B != 255
# 3600 0.45s aux.var.: MLT, QDLat
# 3600 0.632s model: CHAOS-Core
# 3600 1.23s model: CHAOS-Static80
# 3600 1.58s model: CHAOS-Static
# 3600 2.01s model: CHAOS-MMA-Primary
# 3600 1.99s model: CHAOS-MMA-Secondary
# 3600 3.75s model: CHAOS-MMA
# 3600 4.36s model: CHAOS80
# 3600 4.85s model: CHAOS
# 3600 1.17s model: MIO_SHA_2C-Primary
# 3600 1.07s model: MIO_SHA_2C-Secondary
# 3600 1.76s model: MIO_SHA_2C
# PT1H pass #2
# 3600 0.853s plain request
# 3600 0.4s plain request (cached)
# 3600 0.428s filter: Flags_B != 255
# 3600 0.355s aux.var.: MLT, QDLat
# 3600 0.659s model: CHAOS-Core
# 3600 1.24s model: CHAOS-Static80
# 3600 1.58s model: CHAOS-Static
# 3600 2.02s model: CHAOS-MMA-Primary
# 3600 2.14s model: CHAOS-MMA-Secondary
# 3600 3.87s model: CHAOS-MMA
# 3600 4.53s model: CHAOS80
# 3600 4.91s model: CHAOS
# 3600 1.18s model: MIO_SHA_2C-Primary
# 3600 1.07s model: MIO_SHA_2C-Secondary
# 3600 1.88s model: MIO_SHA_2C
# PT1H pass #3
# 3600 0.571s plain request
# 3600 0.495s plain request (cached)
# 3600 0.421s filter: Flags_B != 255
# 3600 0.475s aux.var.: MLT, QDLat
# 3600 0.565s model: CHAOS-Core
# 3600 1.21s model: CHAOS-Static80
# 3600 1.67s model: CHAOS-Static
# 3600 2.02s model: CHAOS-MMA-Primary
# 3600 2s model: CHAOS-MMA-Secondary
# 3600 3.47s model: CHAOS-MMA
# 3600 4.33s model: CHAOS80
# 3600 4.83s model: CHAOS
# 3600 1.13s model: MIO_SHA_2C-Primary
# 3600 1.16s model: MIO_SHA_2C-Secondary
# 3600 1.81s model: MIO_SHA_2C
# PT1H pass #4
# 3600 0.758s plain request
# 3600 0.391s plain request (cached)
# 3600 0.444s filter: Flags_B != 255
# 3600 0.423s aux.var.: MLT, QDLat
# 3600 0.598s model: CHAOS-Core
# 3600 1.3s model: CHAOS-Static80
# 3600 1.7s model: CHAOS-Static
# 3600 1.98s model: CHAOS-MMA-Primary
# 3600 2.01s model: CHAOS-MMA-Secondary
# 3600 3.62s model: CHAOS-MMA
# 3600 4.5s model: CHAOS80
# 3600 5.14s model: CHAOS
# 3600 1.21s model: MIO_SHA_2C-Primary
# 3600 1.13s model: MIO_SHA_2C-Secondary
# 3600 1.78s model: MIO_SHA_2C
# PT1H pass #5
# 3600 0.592s plain request
# 3600 0.381s plain request (cached)
# 3600 0.402s filter: Flags_B != 255
# 3600 0.41s aux.var.: MLT, QDLat
# 3600 0.647s model: CHAOS-Core
# 3600 1.21s model: CHAOS-Static80
# 3600 1.76s model: CHAOS-Static
# 3600 2.01s model: CHAOS-MMA-Primary
# 3600 1.97s model: CHAOS-MMA-Secondary
# 3600 4.29s model: CHAOS-MMA
# 3600 4.74s model: CHAOS80
# 3600 5.48s model: CHAOS
# 3600 1.34s model: MIO_SHA_2C-Primary
# 3600 1.21s model: MIO_SHA_2C-Secondary
# 3600 1.83s model: MIO_SHA_2C
# PT1H pass #6
# 3600 1.38s plain request
# 3600 0.469s plain request (cached)
# 3600 0.458s filter: Flags_B != 255
# 3600 0.578s aux.var.: MLT, QDLat
# 3600 0.697s model: CHAOS-Core
# 3600 1.2s model: CHAOS-Static80
# 3600 1.58s model: CHAOS-Static
# 3600 2.38s model: CHAOS-MMA-Primary
# 3600 2.18s model: CHAOS-MMA-Secondary
# 3600 3.67s model: CHAOS-MMA
# 3600 4.78s model: CHAOS80
# 3600 5.13s model: CHAOS
# 3600 1.72s model: MIO_SHA_2C-Primary
# 3600 1.15s model: MIO_SHA_2C-Secondary
# 3600 1.93s model: MIO_SHA_2C
# PT1H pass #7
# 3600 1.46s plain request
# 3600 0.409s plain request (cached)
# 3600 0.377s filter: Flags_B != 255
# 3600 0.521s aux.var.: MLT, QDLat
# 3600 0.623s model: CHAOS-Core
# 3600 1.23s model: CHAOS-Static80
# 3600 1.72s model: CHAOS-Static
# 3600 2.15s model: CHAOS-MMA-Primary
# 3600 2.18s model: CHAOS-MMA-Secondary
# 3600 3.88s model: CHAOS-MMA
# 3600 4.64s model: CHAOS80
# 3600 4.92s model: CHAOS
# 3600 1.17s model: MIO_SHA_2C-Primary
# 3600 1.2s model: MIO_SHA_2C-Secondary
# 3600 1.81s model: MIO_SHA_2C
# PT1H pass #8
# 3600 0.811s plain request
# 3600 0.399s plain request (cached)
# 3600 0.382s filter: Flags_B != 255
# 3600 0.465s aux.var.: MLT, QDLat
# 3600 0.645s model: CHAOS-Core
# 3600 1.23s model: CHAOS-Static80
# 3600 1.6s model: CHAOS-Static
# 3600 2.06s model: CHAOS-MMA-Primary
# 3600 2.04s model: CHAOS-MMA-Secondary
# 3600 3.69s model: CHAOS-MMA
# 3600 4.57s model: CHAOS80
# 3600 5.04s model: CHAOS
# 3600 1.12s model: MIO_SHA_2C-Primary
# 3600 1.21s model: MIO_SHA_2C-Secondary
# 3600 1.8s model: MIO_SHA_2C
# PT1H pass #9
# 3600 0.736s plain request
# 3600 0.295s plain request (cached)
# 3600 0.359s filter: Flags_B != 255
# 3600 0.394s aux.var.: MLT, QDLat
# 3600 0.634s model: CHAOS-Core
# 3600 1.19s model: CHAOS-Static80
# 3600 1.62s model: CHAOS-Static
# 3600 1.99s model: CHAOS-MMA-Primary
# 3600 2.01s model: CHAOS-MMA-Secondary
# 3600 3.76s model: CHAOS-MMA
# 3600 4.52s model: CHAOS80
# 3600 5s model: CHAOS
# 3600 1.18s model: MIO_SHA_2C-Primary
# 3600 1.1s model: MIO_SHA_2C-Secondary
# 3600 1.86s model: MIO_SHA_2C
# PT1H pass #10
# 3600 0.776s plain request
# 3600 0.428s plain request (cached)
# 3600 0.38s filter: Flags_B != 255
# 3600 0.467s aux.var.: MLT, QDLat
# 3600 0.663s model: CHAOS-Core
# 3600 1.23s model: CHAOS-Static80
# 3600 1.64s model: CHAOS-Static
# 3600 2.04s model: CHAOS-MMA-Primary
# 3600 2.09s model: CHAOS-MMA-Secondary
# 3600 3.71s model: CHAOS-MMA
# 3600 4.56s model: CHAOS80
# 3600 5.03s model: CHAOS
# 3600 1.16s model: MIO_SHA_2C-Primary
# 3600 1.09s model: MIO_SHA_2C-Secondary
# 3600 1.84s model: MIO_SHA_2C
# PT5M pass #1
# 300 0.785s plain request
# 300 0.32s plain request (cached)
# 300 0.326s filter: Flags_B != 255
# 300 0.339s aux.var.: MLT, QDLat
# 300 0.4s model: CHAOS-Core
# 300 0.416s model: CHAOS-Static80
# 300 0.466s model: CHAOS-Static
# 300 0.496s model: CHAOS-MMA-Primary
# 300 0.5s model: CHAOS-MMA-Secondary
# 300 0.607s model: CHAOS-MMA
# 300 0.635s model: CHAOS80
# 300 0.775s model: CHAOS
# 300 0.422s model: MIO_SHA_2C-Primary
# 300 0.311s model: MIO_SHA_2C-Secondary
# 300 0.495s model: MIO_SHA_2C
# PT5M pass #2
# 300 1.22s plain request
# 300 0.324s plain request (cached)
# 300 0.321s filter: Flags_B != 255
# 300 0.347s aux.var.: MLT, QDLat
# 300 0.47s model: CHAOS-Core
# 300 0.388s model: CHAOS-Static80
# 300 0.417s model: CHAOS-Static
# 300 0.61s model: CHAOS-MMA-Primary
# 300 0.455s model: CHAOS-MMA-Secondary
# 300 0.637s model: CHAOS-MMA
# 300 0.725s model: CHAOS80
# 300 0.721s model: CHAOS
# 300 0.416s model: MIO_SHA_2C-Primary
# 300 0.378s model: MIO_SHA_2C-Secondary
# 300 0.441s model: MIO_SHA_2C
# PT5M pass #3
# 300 0.638s plain request
# 300 0.349s plain request (cached)
# 300 0.364s filter: Flags_B != 255
# 300 0.323s aux.var.: MLT, QDLat
# 300 0.365s model: CHAOS-Core
# 300 0.4s model: CHAOS-Static80
# 300 0.42s model: CHAOS-Static
# 300 0.489s model: CHAOS-MMA-Primary
# 300 0.578s model: CHAOS-MMA-Secondary
# 300 0.626s model: CHAOS-MMA
# 300 0.702s model: CHAOS80
# 300 0.628s model: CHAOS
# 300 0.416s model: MIO_SHA_2C-Primary
# 300 0.377s model: MIO_SHA_2C-Secondary
# 300 0.435s model: MIO_SHA_2C
# PT5M pass #4
# 300 0.414s plain request
# 300 0.346s plain request (cached)
# 300 0.323s filter: Flags_B != 255
# 300 0.399s aux.var.: MLT, QDLat
# 300 0.428s model: CHAOS-Core
# 300 0.342s model: CHAOS-Static80
# 300 0.448s model: CHAOS-Static
# 300 0.515s model: CHAOS-MMA-Primary
# 300 0.403s model: CHAOS-MMA-Secondary
# 300 0.564s model: CHAOS-MMA
# 300 0.639s model: CHAOS80
# 300 0.756s model: CHAOS
# 300 0.395s model: MIO_SHA_2C-Primary
# 300 0.319s model: MIO_SHA_2C-Secondary
# 300 0.393s model: MIO_SHA_2C
# PT5M pass #5
# 300 0.994s plain request
# 300 0.311s plain request (cached)
# 300 0.246s filter: Flags_B != 255
# 300 0.28s aux.var.: MLT, QDLat
# 300 0.314s model: CHAOS-Core
# 300 0.322s model: CHAOS-Static80
# 300 0.424s model: CHAOS-Static
# 300 0.438s model: CHAOS-MMA-Primary
# 300 0.42s model: CHAOS-MMA-Secondary
# 300 0.566s model: CHAOS-MMA
# 300 0.671s model: CHAOS80
# 300 0.712s model: CHAOS
# 300 0.311s model: MIO_SHA_2C-Primary
# 300 0.388s model: MIO_SHA_2C-Secondary
# 300 0.394s model: MIO_SHA_2C
# PT5M pass #6
# 300 0.457s plain request
# 300 0.287s plain request (cached)
# 300 0.298s filter: Flags_B != 255
# 300 0.271s aux.var.: MLT, QDLat
# 300 0.254s model: CHAOS-Core
# 300 0.315s model: CHAOS-Static80
# 300 0.34s model: CHAOS-Static
# 300 0.408s model: CHAOS-MMA-Primary
# 300 0.531s model: CHAOS-MMA-Secondary
# 300 0.637s model: CHAOS-MMA
# 300 0.669s model: CHAOS80
# 300 0.624s model: CHAOS
# 300 0.373s model: MIO_SHA_2C-Primary
# 300 0.341s model: MIO_SHA_2C-Secondary
# 300 0.472s model: MIO_SHA_2C
# PT5M pass #7
# 300 0.662s plain request
# 300 0.229s plain request (cached)
# 300 0.253s filter: Flags_B != 255
# 300 0.233s aux.var.: MLT, QDLat
# 300 0.339s model: CHAOS-Core
# 300 0.388s model: CHAOS-Static80
# 300 0.418s model: CHAOS-Static
# 300 0.482s model: CHAOS-MMA-Primary
# 300 0.482s model: CHAOS-MMA-Secondary
# 300 0.594s model: CHAOS-MMA
# 300 0.7s model: CHAOS80
# 300 0.648s model: CHAOS
# 300 0.391s model: MIO_SHA_2C-Primary
# 300 0.442s model: MIO_SHA_2C-Secondary
# 300 0.429s model: MIO_SHA_2C
# PT5M pass #8
# 300 0.835s plain request
# 300 0.311s plain request (cached)
# 300 0.32s filter: Flags_B != 255
# 300 0.318s aux.var.: MLT, QDLat
# 300 0.332s model: CHAOS-Core
# 300 0.387s model: CHAOS-Static80
# 300 0.347s model: CHAOS-Static
# 300 0.481s model: CHAOS-MMA-Primary
# 300 0.469s model: CHAOS-MMA-Secondary
# 300 0.569s model: CHAOS-MMA
# 300 0.657s model: CHAOS80
# 300 0.623s model: CHAOS
# 300 0.375s model: MIO_SHA_2C-Primary
# 300 0.378s model: MIO_SHA_2C-Secondary
# 300 0.444s model: MIO_SHA_2C
# PT5M pass #9
# 300 0.427s plain request
# 300 0.323s plain request (cached)
# 300 0.324s filter: Flags_B != 255
# 300 0.315s aux.var.: MLT, QDLat
# 300 0.337s model: CHAOS-Core
# 300 0.392s model: CHAOS-Static80
# 300 0.421s model: CHAOS-Static
# 300 0.48s model: CHAOS-MMA-Primary
# 300 0.479s model: CHAOS-MMA-Secondary
# 300 0.6s model: CHAOS-MMA
# 300 0.606s model: CHAOS80
# 300 0.635s model: CHAOS
# 300 0.333s model: MIO_SHA_2C-Primary
# 300 0.333s model: MIO_SHA_2C-Secondary
# 300 0.392s model: MIO_SHA_2C
# PT5M pass #10
# 300 0.54s plain request
# 300 0.281s plain request (cached)
# 300 0.275s filter: Flags_B != 255
# 300 0.31s aux.var.: MLT, QDLat
# 300 0.306s model: CHAOS-Core
# 300 0.501s model: CHAOS-Static80
# 300 0.388s model: CHAOS-Static
# 300 0.423s model: CHAOS-MMA-Primary
# 300 0.432s model: CHAOS-MMA-Secondary
# 300 0.546s model: CHAOS-MMA
# 300 0.62s model: CHAOS80
# 300 0.636s model: CHAOS
# 300 0.343s model: MIO_SHA_2C-Primary
# 300 0.333s model: MIO_SHA_2C-Secondary
# 300 0.39s model: MIO_SHA_2C
