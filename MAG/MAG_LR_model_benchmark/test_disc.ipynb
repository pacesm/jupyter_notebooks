# %% [markdown]
# ## VirES - magnetic model benchmark - staging DISC server
#
# Assess perfomance of the VirES magnetic model evaluation and other parameters wrt. the plain data rerival.
# Get per sample times.
#
# See also [VirES Python Client](https://github.com/ESA-VirES/VirES-Python-Client)

# %%
from benchmark import get_random_collection, run_benchmark_set, write_record

SERVER_URL = "https://staging.viresdisc.vires.services"
FILENAME = "results/2022-11-14_disc_benchmark.log"

COLLECTIONS = ["SW_OPER_MAGA_LR_1B", "SW_OPER_MAGB_LR_1B", "SW_OPER_MAGC_LR_1B"]

MODELS = [
    "CHAOS-Core",
    "CHAOS-Static80 = 'CHAOS-Static'(max_degree=80)",
    "CHAOS-Static",
    "CHAOS-MMA-Primary",
    "CHAOS-MMA-Secondary",
    "CHAOS-MMA",
    "CHAOS80 = 'CHAOS-Core' + 'CHAOS-Static'(max_degree=80) + 'CHAOS-MMA-Primary' + 'CHAOS-MMA-Secondary'",
    "CHAOS",
    "MIO_SHA_2C-Primary",
    "MIO_SHA_2C-Secondary",
    "MIO_SHA_2C",
]

TEST_CASES = [
    dict(description="plain request"),
    dict(description="plain request (cached)"),
    dict(description="filter: Flags_B != 255", filters=["Flags_B != 255"]),
    dict(description="aux.var.: MLT, QDLat", auxiliaries=["MLT", "QDLat"]),
    *(
        dict(description=f"model: { model.partition('=')[0].strip() }", models=[model])
        for model in MODELS 
    ),
]

N_RUNS = 10

SELECTION_TIMES = [
    "P1D",
    "PT6H",
    "PT1H",
    "PT5M",
]


with open(FILENAME, "a", encoding="utf8") as log_file:
    for selection_time in SELECTION_TIMES:
        for idx in range(N_RUNS):
            print(f"{selection_time} pass #{idx+1}")
            collection = get_random_collection(COLLECTIONS)
            for record in run_benchmark_set(SERVER_URL, collection, selection_time, TEST_CASES):
                write_record(record, log_file)
# Out:
# P1D pass #1
# 86400 0.74s plain request
# 86400 0.291s plain request (cached)
# 86400 0.308s filter: Flags_B != 255
# 86400 0.9s aux.var.: MLT, QDLat
# 86400 4.6s model: CHAOS-Core
# 86400 22.1s model: CHAOS-Static80
# 86400 32.4s model: CHAOS-Static
# 86400 44.4s model: CHAOS-MMA-Primary
# 86400 46s model: CHAOS-MMA-Secondary
# 86400 91.5s model: CHAOS-MMA
# 86400 116s model: CHAOS80
# 86400 126s model: CHAOS
# 86400 18.5s model: MIO_SHA_2C-Primary
# 86400 18.8s model: MIO_SHA_2C-Secondary
# 86400 36.8s model: MIO_SHA_2C
# P1D pass #2
# 86400 0.688s plain request
# 86400 0.322s plain request (cached)
# 86400 0.474s filter: Flags_B != 255
# 86400 0.63s aux.var.: MLT, QDLat
# 86400 4.5s model: CHAOS-Core
# 86400 22.1s model: CHAOS-Static80
# 86400 32.5s model: CHAOS-Static
# 86400 45.7s model: CHAOS-MMA-Primary
# 86400 47.2s model: CHAOS-MMA-Secondary
# 86400 92.9s model: CHAOS-MMA
# 86400 116s model: CHAOS80
# 86400 127s model: CHAOS
# 86400 18.9s model: MIO_SHA_2C-Primary
# 86400 18.8s model: MIO_SHA_2C-Secondary
# 86400 37s model: MIO_SHA_2C
# P1D pass #3
# 86400 0.579s plain request
# 86400 0.424s plain request (cached)
# 86400 0.291s filter: Flags_B != 255
# 86400 0.515s aux.var.: MLT, QDLat
# 86400 4.5s model: CHAOS-Core
# 86400 22s model: CHAOS-Static80
# 86400 32.5s model: CHAOS-Static
# 86400 44.8s model: CHAOS-MMA-Primary
# 86400 45.4s model: CHAOS-MMA-Secondary
# 86400 90.4s model: CHAOS-MMA
# 86400 115s model: CHAOS80
# 86400 127s model: CHAOS
# 86400 18.7s model: MIO_SHA_2C-Primary
# 86400 18.9s model: MIO_SHA_2C-Secondary
# 86400 36.8s model: MIO_SHA_2C
# P1D pass #4
# 86400 0.713s plain request
# 86400 0.447s plain request (cached)
# 86400 0.298s filter: Flags_B != 255
# 86400 0.433s aux.var.: MLT, QDLat
# 86400 4.38s model: CHAOS-Core
# 86400 22.1s model: CHAOS-Static80
# 86400 32.8s model: CHAOS-Static
# 86400 45.7s model: CHAOS-MMA-Primary
# 86400 45.4s model: CHAOS-MMA-Secondary
# 86400 90.7s model: CHAOS-MMA
# 86400 116s model: CHAOS80
# 86400 127s model: CHAOS
# 86400 18.8s model: MIO_SHA_2C-Primary
# 86400 18.6s model: MIO_SHA_2C-Secondary
# 86400 36.6s model: MIO_SHA_2C
# P1D pass #5
# 86400 0.677s plain request
# 86400 0.394s plain request (cached)
# 86400 0.269s filter: Flags_B != 255
# 86400 0.439s aux.var.: MLT, QDLat
# 86400 4.37s model: CHAOS-Core
# 86400 21.8s model: CHAOS-Static80
# 86400 32.4s model: CHAOS-Static
# 86400 46.6s model: CHAOS-MMA-Primary
# 86400 46.2s model: CHAOS-MMA-Secondary
# 86400 90.6s model: CHAOS-MMA
# 86400 115s model: CHAOS80
# 86400 22s model: CHAOS-Static80
# 86400 32.5s model: CHAOS-Static
# 86400 45.8s model: CHAOS-MMA-Primary
# 86400 47s model: CHAOS-MMA-Secondary
# 86400 90.1s model: CHAOS-MMA
# 86400 127s model: CHAOS
# 86400 18.8s model: MIO_SHA_2C-Primary
# 86400 18.8s model: MIO_SHA_2C-Secondary
# 86400 37.3s model: MIO_SHA_2C
# P1D pass #7
# 86400 0.566s plain request
# 86400 0.438s plain request (cached)
# 86400 0.309s filter: Flags_B != 255
# 86400 0.468s aux.var.: MLT, QDLat
# 86400 4.31s model: CHAOS-Core
# 86400 32.4s model: CHAOS-Static
# 86400 46s model: CHAOS-MMA-Primary
# 86400 47.5s model: CHAOS-MMA-Secondary
# 86400 116s model: CHAOS80
# 86400 128s model: CHAOS
# 86400 18.7s model: MIO_SHA_2C-Primary
# 86400 18.4s model: MIO_SHA_2C-Secondary
# 86400 37s model: MIO_SHA_2C
# P1D pass #8
# 86400 0.636s plain request
# 86400 0.339s plain request (cached)
# 86400 0.49s filter: Flags_B != 255
# 86400 0.47s aux.var.: MLT, QDLat
# 86400 4.37s model: CHAOS-Core
# 86400 21.9s model: CHAOS-Static80
# 86400 32.5s model: CHAOS-Static
# 86400 45.6s model: CHAOS-MMA-Primary
# 86400 44.3s model: CHAOS-MMA-Secondary
# 86400 91.7s model: CHAOS-MMA
# 86400 117s model: CHAOS80
# 86400 127s model: CHAOS
# 86400 18.9s model: MIO_SHA_2C-Primary
# 86400 18.7s model: MIO_SHA_2C-Secondary
# 86400 36.4s model: MIO_SHA_2C
# P1D pass #9
# 86400 0.589s plain request
# 86400 0.275s plain request (cached)
# 86400 0.332s filter: Flags_B != 255
# 86400 0.592s aux.var.: MLT, QDLat
# 86400 4.34s model: CHAOS-Core
# 86400 22s model: CHAOS-Static80
# 86400 32.4s model: CHAOS-Static
# 86400 45.2s model: CHAOS-MMA-Primary
# 86400 41.7s model: CHAOS-MMA-Secondary
# 86400 116s model: CHAOS80
# 86400 126s model: CHAOS
# 86400 18.6s model: MIO_SHA_2C-Primary
# 86400 19.1s model: MIO_SHA_2C-Secondary
# 86400 36.9s model: MIO_SHA_2C
# P1D pass #10
# 86400 0.775s plain request
# 86400 0.267s plain request (cached)
# 86400 0.291s filter: Flags_B != 255
# 86400 0.603s aux.var.: MLT, QDLat
# 86400 4.51s model: CHAOS-Core
# 86400 21.8s model: CHAOS-Static80
# 86400 32.5s model: CHAOS-Static
# 86400 45.3s model: CHAOS-MMA-Primary
# 86400 45.3s model: CHAOS-MMA-Secondary
# 86400 91.2s model: CHAOS-MMA
# 86400 117s model: CHAOS80
# 86400 125s model: CHAOS
# 86400 18.6s model: MIO_SHA_2C-Primary
# 86400 18.9s model: MIO_SHA_2C-Secondary
# 86400 37.1s model: MIO_SHA_2C
# PT6H pass #1
# 21600 0.372s plain request
# 21600 0.184s plain request (cached)
# 21600 0.281s filter: Flags_B != 255
# 21600 0.253s aux.var.: MLT, QDLat
# 21600 1.28s model: CHAOS-Core
# 21600 5.69s model: CHAOS-Static80
# 21600 8.24s model: CHAOS-Static
# 21600 11.7s model: CHAOS-MMA-Primary
# 21600 11.4s model: CHAOS-MMA-Secondary
# 21600 23s model: CHAOS-MMA
# 21600 29.1s model: CHAOS80
# 21600 32.3s model: CHAOS
# 21600 4.89s model: MIO_SHA_2C-Primary
# 21600 4.71s model: MIO_SHA_2C-Secondary
# 21600 9.51s model: MIO_SHA_2C
# PT6H pass #2
# 21600 0.394s plain request
# 21600 0.169s plain request (cached)
# 21600 0.244s filter: Flags_B != 255
# 21600 0.495s aux.var.: MLT, QDLat
# 21600 1.25s model: CHAOS-Core
# 21600 5.73s model: CHAOS-Static80
# 21600 8.43s model: CHAOS-Static
# 21600 11.5s model: CHAOS-MMA-Primary
# 21600 11.5s model: CHAOS-MMA-Secondary
# 21600 22.7s model: CHAOS-MMA
# 21600 28.1s model: CHAOS80
# 21600 31.7s model: CHAOS
# 21600 4.96s model: MIO_SHA_2C-Primary
# 21600 5.05s model: MIO_SHA_2C-Secondary
# 21600 9.47s model: MIO_SHA_2C
# PT6H pass #3
# 21600 0.405s plain request
# 21600 0.162s plain request (cached)
# 21600 0.264s filter: Flags_B != 255
# 21600 0.232s aux.var.: MLT, QDLat
# 21600 1.19s model: CHAOS-Core
# 21600 5.75s model: CHAOS-Static80
# 21600 8.35s model: CHAOS-Static
# 21600 12.2s model: CHAOS-MMA-Primary
# 21600 11.6s model: CHAOS-MMA-Secondary
# 21600 23s model: CHAOS-MMA
# 21600 29.1s model: CHAOS80
# 21600 32.1s model: CHAOS
# 21600 4.94s model: MIO_SHA_2C-Primary
# 21600 4.97s model: MIO_SHA_2C-Secondary
# 21600 9.43s model: MIO_SHA_2C
# PT6H pass #4
# 21600 0.398s plain request
# 21600 0.345s plain request (cached)
# 21600 0.312s filter: Flags_B != 255
# 21600 0.456s aux.var.: MLT, QDLat
# 21600 1.4s model: CHAOS-Core
# 21600 5.71s model: CHAOS-Static80
# 21600 8.28s model: CHAOS-Static
# 21600 11.6s model: CHAOS-MMA-Primary
# 21600 11.8s model: CHAOS-MMA-Secondary
# 21600 22.5s model: CHAOS-MMA
# 21600 29.4s model: CHAOS80
# 21600 32s model: CHAOS
# 21600 4.87s model: MIO_SHA_2C-Primary
# 21600 4.83s model: MIO_SHA_2C-Secondary
# 21600 9.37s model: MIO_SHA_2C
# PT6H pass #5
# 21600 0.386s plain request
# 21600 0.204s plain request (cached)
# 21600 0.25s filter: Flags_B != 255
# 21600 0.525s aux.var.: MLT, QDLat
# 21600 1.27s model: CHAOS-Core
# 21600 5.6s model: CHAOS-Static80
# 21600 8.27s model: CHAOS-Static
# 21600 11.7s model: CHAOS-MMA-Primary
# 21600 11.5s model: CHAOS-MMA-Secondary
# 21600 21.9s model: CHAOS-MMA
# 21600 29s model: CHAOS80
# 21600 31.1s model: CHAOS
# 21600 4.81s model: MIO_SHA_2C-Primary
# 21600 4.81s model: MIO_SHA_2C-Secondary
# 21600 9.46s model: MIO_SHA_2C
# PT6H pass #6
# 21600 0.472s plain request
# 21600 0.225s plain request (cached)
# 21600 0.321s filter: Flags_B != 255
# 21600 0.3s aux.var.: MLT, QDLat
# 21600 1.18s model: CHAOS-Core
# 21600 5.67s model: CHAOS-Static80
# 21600 8.22s model: CHAOS-Static
# 21600 11.7s model: CHAOS-MMA-Primary
# 21600 11.6s model: CHAOS-MMA-Secondary
# 21600 22.4s model: CHAOS-MMA
# 21600 28.9s model: CHAOS80
# 21600 31.9s model: CHAOS
# 21600 4.89s model: MIO_SHA_2C-Primary
# 21600 4.87s model: MIO_SHA_2C-Secondary
# 21600 9.42s model: MIO_SHA_2C
# PT6H pass #7
# 21600 0.485s plain request
# 21600 0.264s plain request (cached)
# 21600 0.226s filter: Flags_B != 255
# 21600 0.292s aux.var.: MLT, QDLat
# 21600 1.43s model: CHAOS-Core
# 21600 5.67s model: CHAOS-Static80
# 21600 8.26s model: CHAOS-Static
# 21600 12.2s model: CHAOS-MMA-Primary
# 21600 12.6s model: CHAOS-MMA-Secondary
# 21600 23s model: CHAOS-MMA
# 21600 29.3s model: CHAOS80
# 21600 31.7s model: CHAOS
# 21600 4.88s model: MIO_SHA_2C-Primary
# 21600 4.8s model: MIO_SHA_2C-Secondary
# 21600 9.51s model: MIO_SHA_2C
# PT6H pass #8
# 21600 0.519s plain request
# 21600 0.296s plain request (cached)
# 21600 0.367s filter: Flags_B != 255
# 21600 0.319s aux.var.: MLT, QDLat
# 21600 1.27s model: CHAOS-Core
# 21600 5.63s model: CHAOS-Static80
# 21600 8.24s model: CHAOS-Static
# 21600 11.7s model: CHAOS-MMA-Primary
# 21600 11.7s model: CHAOS-MMA-Secondary
# 21600 22.8s model: CHAOS-MMA
# 21600 29.3s model: CHAOS80
# 21600 31.7s model: CHAOS
# 21600 4.87s model: MIO_SHA_2C-Primary
# 21600 4.87s model: MIO_SHA_2C-Secondary
# 21600 9.51s model: MIO_SHA_2C
# PT6H pass #9
# 21600 0.627s plain request
# 21600 0.239s plain request (cached)
# 21600 0.303s filter: Flags_B != 255
# 21600 0.406s aux.var.: MLT, QDLat
# 21600 1.3s model: CHAOS-Core
# 21600 5.62s model: CHAOS-Static80
# 21600 8.3s model: CHAOS-Static
# 21600 11.3s model: CHAOS-MMA-Primary
# 21600 11.3s model: CHAOS-MMA-Secondary
# 21600 22.8s model: CHAOS-MMA
# 21600 29.4s model: CHAOS80
# 21600 32.1s model: CHAOS
# 21600 4.97s model: MIO_SHA_2C-Primary
# 21600 4.91s model: MIO_SHA_2C-Secondary
# 21600 9.71s model: MIO_SHA_2C
# PT6H pass #10
# 21600 0.531s plain request
# 21600 0.341s plain request (cached)
# 21600 0.334s filter: Flags_B != 255
# 21600 0.216s aux.var.: MLT, QDLat
# 21600 1.32s model: CHAOS-Core
# 21600 5.74s model: CHAOS-Static80
# 21600 8.26s model: CHAOS-Static
# 21600 11.6s model: CHAOS-MMA-Primary
# 21600 11.7s model: CHAOS-MMA-Secondary
# 21600 22.6s model: CHAOS-MMA
# 21600 29.4s model: CHAOS80
# 21600 32s model: CHAOS
# 21600 4.86s model: MIO_SHA_2C-Primary
# 21600 4.95s model: MIO_SHA_2C-Secondary
# 21600 9.34s model: MIO_SHA_2C
# PT1H pass #1
# 3600 0.295s plain request
# 3600 0.178s plain request (cached)
# 3600 0.18s filter: Flags_B != 255
# 3600 0.21s aux.var.: MLT, QDLat
# 3600 0.341s model: CHAOS-Core
# 3600 1.11s model: CHAOS-Static80
# 3600 1.5s model: CHAOS-Static
# 3600 2.15s model: CHAOS-MMA-Primary
# 3600 2.15s model: CHAOS-MMA-Secondary
# 3600 3.88s model: CHAOS-MMA
# 3600 5.18s model: CHAOS80
# 3600 5.54s model: CHAOS
# 3600 1s model: MIO_SHA_2C-Primary
# 3600 0.951s model: MIO_SHA_2C-Secondary
# 3600 1.7s model: MIO_SHA_2C
# PT1H pass #2
# 3600 0.365s plain request
# 3600 0.191s plain request (cached)
# 3600 0.192s filter: Flags_B != 255
# 3600 0.234s aux.var.: MLT, QDLat
# 3600 0.378s model: CHAOS-Core
# 3600 1.13s model: CHAOS-Static80
# 3600 1.49s model: CHAOS-Static
# 3600 2.15s model: CHAOS-MMA-Primary
# 3600 2.15s model: CHAOS-MMA-Secondary
# 3600 4.41s model: CHAOS-MMA
# 3600 5.45s model: CHAOS80
# 3600 6.05s model: CHAOS
# 3600 0.94s model: MIO_SHA_2C-Primary
# 3600 0.929s model: MIO_SHA_2C-Secondary
# 3600 1.77s model: MIO_SHA_2C
# PT1H pass #3
# 3600 0.329s plain request
# 3600 0.141s plain request (cached)
# 3600 0.159s filter: Flags_B != 255
# 3600 0.164s aux.var.: MLT, QDLat
# 3600 0.314s model: CHAOS-Core
# 3600 1.1s model: CHAOS-Static80
# 3600 1.56s model: CHAOS-Static
# 3600 2.12s model: CHAOS-MMA-Primary
# 3600 2.14s model: CHAOS-MMA-Secondary
# 3600 4.03s model: CHAOS-MMA
# 3600 5.2s model: CHAOS80
# 3600 5.62s model: CHAOS
# 3600 0.995s model: MIO_SHA_2C-Primary
# 3600 0.897s model: MIO_SHA_2C-Secondary
# 3600 1.74s model: MIO_SHA_2C
# PT1H pass #4
# 3600 0.301s plain request
# 3600 0.232s plain request (cached)
# 3600 0.202s filter: Flags_B != 255
# 3600 0.207s aux.var.: MLT, QDLat
# 3600 0.414s model: CHAOS-Core
# 3600 1.08s model: CHAOS-Static80
# 3600 1.52s model: CHAOS-Static
# 3600 2.13s model: CHAOS-MMA-Primary
# 3600 2.12s model: CHAOS-MMA-Secondary
# 3600 4.01s model: CHAOS-MMA
# 3600 4.94s model: CHAOS80
# 3600 5.42s model: CHAOS
# 3600 1.02s model: MIO_SHA_2C-Primary
# 3600 0.96s model: MIO_SHA_2C-Secondary
# 3600 1.72s model: MIO_SHA_2C
# PT1H pass #5
# 3600 0.322s plain request
# 3600 0.21s plain request (cached)
# 3600 0.199s filter: Flags_B != 255
# 3600 0.225s aux.var.: MLT, QDLat
# 3600 0.377s model: CHAOS-Core
# 3600 1.07s model: CHAOS-Static80
# 3600 1.48s model: CHAOS-Static
# 3600 2.12s model: CHAOS-MMA-Primary
# 3600 2.06s model: CHAOS-MMA-Secondary
# 3600 4.06s model: CHAOS-MMA
# 3600 5.05s model: CHAOS80
# 3600 5.44s model: CHAOS
# 3600 0.918s model: MIO_SHA_2C-Primary
# 3600 0.956s model: MIO_SHA_2C-Secondary
# 3600 1.72s model: MIO_SHA_2C
# PT1H pass #6
# 3600 0.379s plain request
# 3600 0.207s plain request (cached)
# 3600 0.167s filter: Flags_B != 255
# 3600 0.182s aux.var.: MLT, QDLat
# 3600 0.359s model: CHAOS-Core
# 3600 1.11s model: CHAOS-Static80
# 3600 1.54s model: CHAOS-Static
# 3600 2.09s model: CHAOS-MMA-Primary
# 3600 2.1s model: CHAOS-MMA-Secondary
# 3600 3.93s model: CHAOS-MMA
# 3600 5.1s model: CHAOS80
# 3600 5.45s model: CHAOS
# 3600 0.951s model: MIO_SHA_2C-Primary
# 3600 0.971s model: MIO_SHA_2C-Secondary
# 3600 1.73s model: MIO_SHA_2C
# PT1H pass #7
# 3600 0.416s plain request
# 3600 0.192s plain request (cached)
# 3600 0.15s filter: Flags_B != 255
# 3600 0.184s aux.var.: MLT, QDLat
# 3600 0.383s model: CHAOS-Core
# 3600 1.03s model: CHAOS-Static80
# 3600 1.5s model: CHAOS-Static
# 3600 2.13s model: CHAOS-MMA-Primary
# 3600 2.18s model: CHAOS-MMA-Secondary
# 3600 4.03s model: CHAOS-MMA
# 3600 5.06s model: CHAOS80
# 3600 5.5s model: CHAOS
# 3600 1.03s model: MIO_SHA_2C-Primary
# 3600 0.96s model: MIO_SHA_2C-Secondary
# 3600 1.73s model: MIO_SHA_2C
# PT1H pass #8
# 3600 0.354s plain request
# 3600 0.251s plain request (cached)
# 3600 0.213s filter: Flags_B != 255
# 3600 0.258s aux.var.: MLT, QDLat
# 3600 0.403s model: CHAOS-Core
# 3600 1.11s model: CHAOS-Static80
# 3600 1.49s model: CHAOS-Static
# 3600 2.11s model: CHAOS-MMA-Primary
# 3600 2.12s model: CHAOS-MMA-Secondary
# 3600 4.03s model: CHAOS-MMA
# 3600 5.01s model: CHAOS80
# 3600 5.34s model: CHAOS
# 3600 0.948s model: MIO_SHA_2C-Primary
# 3600 1s model: MIO_SHA_2C-Secondary
# 3600 1.74s model: MIO_SHA_2C
# PT1H pass #9
# 3600 0.328s plain request
# 3600 0.172s plain request (cached)
# 3600 0.185s filter: Flags_B != 255
# 3600 0.208s aux.var.: MLT, QDLat
# 3600 0.387s model: CHAOS-Core
# 3600 1.11s model: CHAOS-Static80
# 3600 1.49s model: CHAOS-Static
# 3600 2.09s model: CHAOS-MMA-Primary
# 3600 2.17s model: CHAOS-MMA-Secondary
# 3600 4.01s model: CHAOS-MMA
# 3600 5.01s model: CHAOS80
# 3600 5.43s model: CHAOS
# 3600 0.952s model: MIO_SHA_2C-Primary
# 3600 1.01s model: MIO_SHA_2C-Secondary
# 3600 1.75s model: MIO_SHA_2C
# PT1H pass #10
# 3600 0.337s plain request
# 3600 0.2s plain request (cached)
# 3600 0.171s filter: Flags_B != 255
# 3600 0.214s aux.var.: MLT, QDLat
# 3600 0.372s model: CHAOS-Core
# 3600 1.07s model: CHAOS-Static80
# 3600 1.51s model: CHAOS-Static
# 3600 2.08s model: CHAOS-MMA-Primary
# 3600 2.13s model: CHAOS-MMA-Secondary
# 3600 4.04s model: CHAOS-MMA
# 3600 5.09s model: CHAOS80
# 3600 5.49s model: CHAOS
# 3600 0.969s model: MIO_SHA_2C-Primary
# 3600 0.959s model: MIO_SHA_2C-Secondary
# 3600 1.68s model: MIO_SHA_2C
# PT5M pass #1
# 300 0.307s plain request
# 300 0.175s plain request (cached)
# 300 0.182s filter: Flags_B != 255
# 300 0.183s aux.var.: MLT, QDLat
# 300 0.198s model: CHAOS-Core
# 300 0.193s model: CHAOS-Static80
# 300 0.293s model: CHAOS-Static
# 300 0.339s model: CHAOS-MMA-Primary
# 300 0.375s model: CHAOS-MMA-Secondary
# 300 0.587s model: CHAOS-MMA
# 300 0.601s model: CHAOS80
# 300 0.626s model: CHAOS
# 300 0.214s model: MIO_SHA_2C-Primary
# 300 0.214s model: MIO_SHA_2C-Secondary
# 300 0.307s model: MIO_SHA_2C
# PT5M pass #2
# 300 0.267s plain request
# 300 0.227s plain request (cached)
# 300 0.194s filter: Flags_B != 255
# 300 0.193s aux.var.: MLT, QDLat
# 300 0.209s model: CHAOS-Core
# 300 0.268s model: CHAOS-Static80
# 300 0.273s model: CHAOS-Static
# 300 0.275s model: CHAOS-MMA-Primary
# 300 0.309s model: CHAOS-MMA-Secondary
# 300 0.44s model: CHAOS-MMA
# 300 0.587s model: CHAOS80
# 300 0.606s model: CHAOS
# 300 0.195s model: MIO_SHA_2C-Primary
# 300 0.263s model: MIO_SHA_2C-Secondary
# 300 0.247s model: MIO_SHA_2C
# PT5M pass #3
# 300 0.322s plain request
# 300 0.191s plain request (cached)
# 300 0.121s filter: Flags_B != 255
# 300 0.193s aux.var.: MLT, QDLat
# 300 0.209s model: CHAOS-Core
# 300 0.282s model: CHAOS-Static80
# 300 0.22s model: CHAOS-Static
# 300 0.328s model: CHAOS-MMA-Primary
# 300 0.342s model: CHAOS-MMA-Secondary
# 300 0.45s model: CHAOS-MMA
# 300 0.526s model: CHAOS80
# 300 0.635s model: CHAOS
# 300 0.244s model: MIO_SHA_2C-Primary
# 300 0.183s model: MIO_SHA_2C-Secondary
# 300 0.246s model: MIO_SHA_2C
# PT5M pass #4
# 300 0.3s plain request
# 300 0.154s plain request (cached)
# 300 0.127s filter: Flags_B != 255
# 300 0.148s aux.var.: MLT, QDLat
# 300 0.151s model: CHAOS-Core
# 300 0.272s model: CHAOS-Static80
# 300 0.296s model: CHAOS-Static
# 300 0.338s model: CHAOS-MMA-Primary
# 300 0.272s model: CHAOS-MMA-Secondary
# 300 0.487s model: CHAOS-MMA
# 300 0.592s model: CHAOS80
# 300 0.552s model: CHAOS
# 300 0.249s model: MIO_SHA_2C-Primary
# 300 0.243s model: MIO_SHA_2C-Secondary
# 300 0.319s model: MIO_SHA_2C
# PT5M pass #5
# 300 0.411s plain request
# 300 0.192s plain request (cached)
# 300 0.12s filter: Flags_B != 255
# 300 0.151s aux.var.: MLT, QDLat
# 300 0.134s model: CHAOS-Core
# 300 0.263s model: CHAOS-Static80
# 300 0.309s model: CHAOS-Static
# 300 0.275s model: CHAOS-MMA-Primary
# 300 0.314s model: CHAOS-MMA-Secondary
# 300 0.547s model: CHAOS-MMA
# 300 0.518s model: CHAOS80
# 300 0.573s model: CHAOS
# 300 0.228s model: MIO_SHA_2C-Primary
# 300 0.252s model: MIO_SHA_2C-Secondary
# 300 0.239s model: MIO_SHA_2C
# PT5M pass #6
# 300 0.175s plain request
# 300 0.111s plain request (cached)
# 300 0.106s filter: Flags_B != 255
# 300 0.121s aux.var.: MLT, QDLat
# 300 0.122s model: CHAOS-Core
# 300 0.215s model: CHAOS-Static80
# 300 0.254s model: CHAOS-Static
# 300 0.274s model: CHAOS-MMA-Primary
# 300 0.401s model: CHAOS-MMA-Secondary
# 300 0.468s model: CHAOS-MMA
# 300 0.588s model: CHAOS80
# 300 0.648s model: CHAOS
# 300 0.245s model: MIO_SHA_2C-Primary
# 300 0.253s model: MIO_SHA_2C-Secondary
# 300 0.332s model: MIO_SHA_2C
# PT5M pass #7
# 300 0.309s plain request
# 300 0.177s plain request (cached)
# 300 0.193s filter: Flags_B != 255
# 300 0.193s aux.var.: MLT, QDLat
# 300 0.201s model: CHAOS-Core
# 300 0.217s model: CHAOS-Static80
# 300 0.235s model: CHAOS-Static
# 300 0.296s model: CHAOS-MMA-Primary
# 300 0.332s model: CHAOS-MMA-Secondary
# 300 0.532s model: CHAOS-MMA
# 300 0.591s model: CHAOS80
# 300 0.619s model: CHAOS
# 300 0.275s model: MIO_SHA_2C-Primary
# 300 0.248s model: MIO_SHA_2C-Secondary
# 300 0.278s model: MIO_SHA_2C
# PT5M pass #8
# 300 0.322s plain request
# 300 0.184s plain request (cached)
# 300 0.13s filter: Flags_B != 255
# 300 0.194s aux.var.: MLT, QDLat
# 300 0.207s model: CHAOS-Core
# 300 0.217s model: CHAOS-Static80
# 300 0.254s model: CHAOS-Static
# 300 0.36s model: CHAOS-MMA-Primary
# 300 0.36s model: CHAOS-MMA-Secondary
# 300 0.487s model: CHAOS-MMA
# 300 0.528s model: CHAOS80
# 300 0.619s model: CHAOS
# 300 0.245s model: MIO_SHA_2C-Primary
# 300 0.175s model: MIO_SHA_2C-Secondary
# 300 0.239s model: MIO_SHA_2C
# PT5M pass #9
# 300 0.287s plain request
# 300 0.107s plain request (cached)
# 300 0.102s filter: Flags_B != 255
# 300 0.205s aux.var.: MLT, QDLat
# 300 0.2s model: CHAOS-Core
# 300 0.262s model: CHAOS-Static80
# 300 0.304s model: CHAOS-Static
# 300 0.353s model: CHAOS-MMA-Primary
# 300 0.272s model: CHAOS-MMA-Secondary
# 300 0.441s model: CHAOS-MMA
# 300 0.536s model: CHAOS80
# 300 0.599s model: CHAOS
# 300 0.184s model: MIO_SHA_2C-Primary
# 300 0.251s model: MIO_SHA_2C-Secondary
# 300 0.276s model: MIO_SHA_2C
# PT5M pass #10
# 300 0.31s plain request
# 300 0.185s plain request (cached)
# 300 0.138s filter: Flags_B != 255
# 300 0.11s aux.var.: MLT, QDLat
# 300 0.2s model: CHAOS-Core
# 300 0.26s model: CHAOS-Static80
# 300 0.285s model: CHAOS-Static
# 300 0.354s model: CHAOS-MMA-Primary
# 300 0.351s model: CHAOS-MMA-Secondary
# 300 0.489s model: CHAOS-MMA
# 300 0.534s model: CHAOS80
# 300 0.66s model: CHAOS
# 300 0.171s model: MIO_SHA_2C-Primary
# 300 0.209s model: MIO_SHA_2C-Secondary
# 300 0.271s model: MIO_SHA_2C
