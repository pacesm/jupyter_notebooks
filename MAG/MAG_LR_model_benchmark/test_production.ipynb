# %% [markdown]
# ## VirES - magnetic model benchmark - production server
#
# Assess perfomance of the VirES magnetic model evaluation and other parameters wrt. the plain data rerival.
# Get per sample times.
#
# See also [VirES Python Client](https://github.com/ESA-VirES/VirES-Python-Client)

# %%
from benchmark import get_random_collection, run_benchmark_set, write_record

SERVER_URL = "https://vires.services"
FILENAME = "results/2022-12-19_production_benchmark.log"

COLLECTIONS = ["SW_OPER_MAGA_LR_1B", "SW_OPER_MAGB_LR_1B", "SW_OPER_MAGC_LR_1B"]

MODELS = [
    "CHAOS-Core",
    "CHAOS-Static80 = 'CHAOS-Static'(max_degree=80)",
    "CHAOS-Static",
    "CHAOS-MMA-Primary",
    "CHAOS-MMA-Secondary",
    "CHAOS-MMA",
    "CHAOS80 = 'CHAOS-Core' + 'CHAOS-Static'(max_degree=80) + 'CHAOS-MMA-Primary' + 'CHAOS-MMA-Secondary'",
    "CHAOS",
    "MIO_SHA_2C-Primary",
    "MIO_SHA_2C-Secondary",
    "MIO_SHA_2C",
]

TEST_CASES = [
    dict(description="plain request"),
    dict(description="plain request (cached)"),
    dict(description="filter: Flags_B != 255", filters=["Flags_B != 255"]),
    dict(description="aux.var.: MLT, QDLat", auxiliaries=["MLT", "QDLat"]),
    *(
        dict(description=f"model: { model.partition('=')[0].strip() }", models=[model])
        for model in MODELS 
    ),
]

N_RUNS = 10

SELECTION_TIMES = [
    "P1D",
    "PT6H",
    "PT1H",
    "PT5M",
]


with open(FILENAME, "a", encoding="utf8") as log_file:
    for selection_time in SELECTION_TIMES:
        for idx in range(N_RUNS):
            print(f"{selection_time} pass #{idx+1}")
            collection = get_random_collection(COLLECTIONS)
            for record in run_benchmark_set(SERVER_URL, collection, selection_time, TEST_CASES):
                write_record(record, log_file)
# Out:
# P1D pass #1
# 86400 0.335s plain request
# 86400 0.245s plain request (cached)
# 86400 0.391s filter: Flags_B != 255
# 86400 0.475s aux.var.: MLT, QDLat
# 86400 0.544s model: CHAOS-Core
# 86400 1.45s model: CHAOS-Static80
# 86400 6.43s model: CHAOS-Static
# 86400 0.371s model: CHAOS-MMA-Primary
# 86400 0.412s model: CHAOS-MMA-Secondary
# 86400 0.51s model: CHAOS-MMA
# 86400 1.84s model: CHAOS80
# 86400 6.86s model: CHAOS
# 86400 3.53s model: MIO_SHA_2C-Primary
# 86400 3.52s model: MIO_SHA_2C-Secondary
# 86400 6.86s model: MIO_SHA_2C
# P1D pass #2
# 86400 0.285s plain request
# 86400 0.224s plain request (cached)
# 86400 0.344s filter: Flags_B != 255
# 86400 0.39s aux.var.: MLT, QDLat
# 86400 0.404s model: CHAOS-Core
# 86400 1.49s model: CHAOS-Static80
# 86400 6.37s model: CHAOS-Static
# 86400 0.457s model: CHAOS-MMA-Primary
# 86400 0.415s model: CHAOS-MMA-Secondary
# 86400 0.657s model: CHAOS-MMA
# 86400 1.89s model: CHAOS80
# 86400 6.7s model: CHAOS
# 86400 3.62s model: MIO_SHA_2C-Primary
# 86400 3.59s model: MIO_SHA_2C-Secondary
# 86400 6.71s model: MIO_SHA_2C
# P1D pass #3
# 86400 0.278s plain request
# 86400 0.284s plain request (cached)
# 86400 0.372s filter: Flags_B != 255
# 86400 0.496s aux.var.: MLT, QDLat
# 86400 0.518s model: CHAOS-Core
# 86400 1.52s model: CHAOS-Static80
# 86400 6.26s model: CHAOS-Static
# 86400 0.419s model: CHAOS-MMA-Primary
# 86400 0.547s model: CHAOS-MMA-Secondary
# 86400 0.546s model: CHAOS-MMA
# 86400 1.86s model: CHAOS80
# 86400 6.67s model: CHAOS
# 86400 3.5s model: MIO_SHA_2C-Primary
# 86400 3.59s model: MIO_SHA_2C-Secondary
# 86400 6.79s model: MIO_SHA_2C
# P1D pass #4
# 86400 0.289s plain request
# 86400 0.403s plain request (cached)
# 86400 0.399s filter: Flags_B != 255
# 86400 0.43s aux.var.: MLT, QDLat
# 86400 0.405s model: CHAOS-Core
# 86400 1.44s model: CHAOS-Static80
# 86400 6.29s model: CHAOS-Static
# 86400 0.419s model: CHAOS-MMA-Primary
# 86400 0.386s model: CHAOS-MMA-Secondary
# 86400 0.672s model: CHAOS-MMA
# 86400 1.85s model: CHAOS80
# 86400 6.71s model: CHAOS
# 86400 3.54s model: MIO_SHA_2C-Primary
# 86400 3.46s model: MIO_SHA_2C-Secondary
# 86400 6.83s model: MIO_SHA_2C
# P1D pass #5
# 86400 0.324s plain request
# 86400 0.248s plain request (cached)
# 86398 0.365s filter: Flags_B != 255
# 86400 0.498s aux.var.: MLT, QDLat
# 86400 0.441s model: CHAOS-Core
# 86400 1.44s model: CHAOS-Static80
# 86400 6.28s model: CHAOS-Static
# 86400 0.368s model: CHAOS-MMA-Primary
# 86400 0.363s model: CHAOS-MMA-Secondary
# 86400 0.466s model: CHAOS-MMA
# 86400 1.75s model: CHAOS80
# 86400 6.65s model: CHAOS
# 86400 3.51s model: MIO_SHA_2C-Primary
# 86400 3.54s model: MIO_SHA_2C-Secondary
# 86400 6.79s model: MIO_SHA_2C
# P1D pass #6
# 86400 0.282s plain request
# 86400 0.262s plain request (cached)
# 86400 0.363s filter: Flags_B != 255
# 86400 0.457s aux.var.: MLT, QDLat
# 86400 0.391s model: CHAOS-Core
# 86400 1.57s model: CHAOS-Static80
# 86400 6.33s model: CHAOS-Static
# 86400 0.431s model: CHAOS-MMA-Primary
# 86400 0.404s model: CHAOS-MMA-Secondary
# 86400 0.489s model: CHAOS-MMA
# 86400 1.98s model: CHAOS80
# 86400 6.73s model: CHAOS
# 86400 3.49s model: MIO_SHA_2C-Primary
# 86400 3.59s model: MIO_SHA_2C-Secondary
# 86400 6.88s model: MIO_SHA_2C
# P1D pass #7
# 86400 0.417s plain request
# 86400 0.219s plain request (cached)
# 86400 0.32s filter: Flags_B != 255
# 86400 0.499s aux.var.: MLT, QDLat
# 86400 0.49s model: CHAOS-Core
# 86400 1.43s model: CHAOS-Static80
# 86400 6.32s model: CHAOS-Static
# 86400 0.444s model: CHAOS-MMA-Primary
# 86400 0.385s model: CHAOS-MMA-Secondary
# 86400 0.534s model: CHAOS-MMA
# 86400 1.96s model: CHAOS80
# 86400 6.66s model: CHAOS
# 86400 3.62s model: MIO_SHA_2C-Primary
# 86400 3.49s model: MIO_SHA_2C-Secondary
# 86400 6.73s model: MIO_SHA_2C
# P1D pass #8
# 86400 0.366s plain request
# 86400 0.225s plain request (cached)
# 86398 0.258s filter: Flags_B != 255
# 86400 0.413s aux.var.: MLT, QDLat
# 86400 0.378s model: CHAOS-Core
# 86400 1.41s model: CHAOS-Static80
# 86400 6.28s model: CHAOS-Static
# 86400 0.463s model: CHAOS-MMA-Primary
# 86400 0.446s model: CHAOS-MMA-Secondary
# 86400 0.545s model: CHAOS-MMA
# 86400 1.73s model: CHAOS80
# 86400 6.61s model: CHAOS
# 86400 3.65s model: MIO_SHA_2C-Primary
# 86400 3.46s model: MIO_SHA_2C-Secondary
# 86400 6.98s model: MIO_SHA_2C
# P1D pass #9
# 86400 0.443s plain request
# 86400 0.25s plain request (cached)
# 86400 0.278s filter: Flags_B != 255
# 86400 0.504s aux.var.: MLT, QDLat
# 86400 0.395s model: CHAOS-Core
# 86400 1.69s model: CHAOS-Static80
# 86400 6.4s model: CHAOS-Static
# 86400 0.545s model: CHAOS-MMA-Primary
# 86400 0.414s model: CHAOS-MMA-Secondary
# 86400 0.452s model: CHAOS-MMA
# 86400 1.76s model: CHAOS80
# 86400 6.5s model: CHAOS
# 86400 3.49s model: MIO_SHA_2C-Primary
# 86400 3.51s model: MIO_SHA_2C-Secondary
# 86400 6.68s model: MIO_SHA_2C
# P1D pass #10
# 86400 0.275s plain request
# 86400 0.295s plain request (cached)
# 86400 0.255s filter: Flags_B != 255
# 86400 0.448s aux.var.: MLT, QDLat
# 86400 0.487s model: CHAOS-Core
# 86400 1.44s model: CHAOS-Static80
# 86400 6.28s model: CHAOS-Static
# 86400 0.364s model: CHAOS-MMA-Primary
# 86400 0.429s model: CHAOS-MMA-Secondary
# 86400 0.542s model: CHAOS-MMA
# 86400 1.89s model: CHAOS80
# 86400 6.74s model: CHAOS
# 86400 3.59s model: MIO_SHA_2C-Primary
# 86400 3.51s model: MIO_SHA_2C-Secondary
# 86400 6.71s model: MIO_SHA_2C
# PT6H pass #1
# 21600 0.262s plain request
# 21600 0.153s plain request (cached)
# 21600 0.164s filter: Flags_B != 255
# 21600 0.258s aux.var.: MLT, QDLat
# 21600 0.273s model: CHAOS-Core
# 21600 0.454s model: CHAOS-Static80
# 21600 1.67s model: CHAOS-Static
# 21600 0.273s model: CHAOS-MMA-Primary
# 21600 0.173s model: CHAOS-MMA-Secondary
# 21600 0.208s model: CHAOS-MMA
# 21600 0.603s model: CHAOS80
# 21600 1.79s model: CHAOS
# 21600 0.991s model: MIO_SHA_2C-Primary
# 21600 1.04s model: MIO_SHA_2C-Secondary
# 21600 1.98s model: MIO_SHA_2C
# PT6H pass #2
# 21600 0.224s plain request
# 21600 0.241s plain request (cached)
# 21600 0.268s filter: Flags_B != 255
# 21600 0.241s aux.var.: MLT, QDLat
# 21600 0.233s model: CHAOS-Core
# 21600 0.618s model: CHAOS-Static80
# 21600 1.7s model: CHAOS-Static
# 21600 0.301s model: CHAOS-MMA-Primary
# 21600 0.302s model: CHAOS-MMA-Secondary
# 21600 0.299s model: CHAOS-MMA
# 21600 0.767s model: CHAOS80
# 21600 1.8s model: CHAOS
# 21600 1.09s model: MIO_SHA_2C-Primary
# 21600 1.04s model: MIO_SHA_2C-Secondary
# 21600 1.87s model: MIO_SHA_2C
# PT6H pass #3
# 21600 0.255s plain request
# 21600 0.167s plain request (cached)
# 21600 0.154s filter: Flags_B != 255
# 21600 0.277s aux.var.: MLT, QDLat
# 21600 0.24s model: CHAOS-Core
# 21600 0.642s model: CHAOS-Static80
# 21600 1.82s model: CHAOS-Static
# 21600 0.245s model: CHAOS-MMA-Primary
# 21600 0.267s model: CHAOS-MMA-Secondary
# 21600 0.268s model: CHAOS-MMA
# 21600 0.725s model: CHAOS80
# 21600 2.09s model: CHAOS
# 21600 0.997s model: MIO_SHA_2C-Primary
# 21600 1.02s model: MIO_SHA_2C-Secondary
# 21600 1.8s model: MIO_SHA_2C
# PT6H pass #4
# 21600 0.244s plain request
# 21600 0.247s plain request (cached)
# 21600 0.19s filter: Flags_B != 255
# 21600 0.233s aux.var.: MLT, QDLat
# 21600 0.27s model: CHAOS-Core
# 21600 0.507s model: CHAOS-Static80
# 21600 1.8s model: CHAOS-Static
# 21600 0.359s model: CHAOS-MMA-Primary
# 21600 0.457s model: CHAOS-MMA-Secondary
# 21600 0.291s model: CHAOS-MMA
# 21600 0.631s model: CHAOS80
# 21600 1.81s model: CHAOS
# 21600 1.03s model: MIO_SHA_2C-Primary
# 21600 1.1s model: MIO_SHA_2C-Secondary
# 21600 1.82s model: MIO_SHA_2C
# PT6H pass #5
# 21600 0.165s plain request
# 21600 0.151s plain request (cached)
# 21600 0.228s filter: Flags_B != 255
# 21600 0.212s aux.var.: MLT, QDLat
# 21600 0.206s model: CHAOS-Core
# 21600 0.478s model: CHAOS-Static80
# 21600 1.68s model: CHAOS-Static
# 21600 0.297s model: CHAOS-MMA-Primary
# 21600 0.409s model: CHAOS-MMA-Secondary
# 21600 0.332s model: CHAOS-MMA
# 21600 0.643s model: CHAOS80
# 21600 1.79s model: CHAOS
# 21600 1.01s model: MIO_SHA_2C-Primary
# 21600 0.976s model: MIO_SHA_2C-Secondary
# 21600 1.94s model: MIO_SHA_2C
# PT6H pass #6
# 21600 0.184s plain request
# 21600 0.167s plain request (cached)
# 21600 0.213s filter: Flags_B != 255
# 21600 0.253s aux.var.: MLT, QDLat
# 21600 0.41s model: CHAOS-Core
# 21600 0.478s model: CHAOS-Static80
# 21600 1.78s model: CHAOS-Static
# 21600 0.363s model: CHAOS-MMA-Primary
# 21600 0.26s model: CHAOS-MMA-Secondary
# 21600 0.273s model: CHAOS-MMA
# 21600 0.687s model: CHAOS80
# 21600 1.92s model: CHAOS
# 21600 0.975s model: MIO_SHA_2C-Primary
# 21600 0.968s model: MIO_SHA_2C-Secondary
# 21600 1.82s model: MIO_SHA_2C
# PT6H pass #7
# 21600 0.188s plain request
# 21600 0.145s plain request (cached)
# 21600 0.204s filter: Flags_B != 255
# 21600 0.187s aux.var.: MLT, QDLat
# 21600 0.221s model: CHAOS-Core
# 21600 0.581s model: CHAOS-Static80
# 21600 1.84s model: CHAOS-Static
# 21600 0.319s model: CHAOS-MMA-Primary
# 21600 0.292s model: CHAOS-MMA-Secondary
# 21600 0.214s model: CHAOS-MMA
# 21600 0.533s model: CHAOS80
# 21600 1.79s model: CHAOS
# 21600 1.01s model: MIO_SHA_2C-Primary
# 21600 1.1s model: MIO_SHA_2C-Secondary
# 21600 1.81s model: MIO_SHA_2C
# PT6H pass #8
# 21600 0.168s plain request
# 21600 0.163s plain request (cached)
# 21600 0.149s filter: Flags_B != 255
# 21600 0.232s aux.var.: MLT, QDLat
# 21600 0.236s model: CHAOS-Core
# 21600 0.48s model: CHAOS-Static80
# 21600 1.65s model: CHAOS-Static
# 21600 0.298s model: CHAOS-MMA-Primary
# 21600 0.264s model: CHAOS-MMA-Secondary
# 21600 0.347s model: CHAOS-MMA
# 21600 0.627s model: CHAOS80
# 21600 1.8s model: CHAOS
# 21600 0.963s model: MIO_SHA_2C-Primary
# 21600 1.06s model: MIO_SHA_2C-Secondary
# 21600 1.84s model: MIO_SHA_2C
# PT6H pass #9
# 21600 0.171s plain request
# 21600 0.307s plain request (cached)
# 21600 0.193s filter: Flags_B != 255
# 21600 0.264s aux.var.: MLT, QDLat
# 21600 0.302s model: CHAOS-Core
# 21600 0.471s model: CHAOS-Static80
# 21600 1.8s model: CHAOS-Static
# 21600 0.227s model: CHAOS-MMA-Primary
# 21600 0.444s model: CHAOS-MMA-Secondary
# 21600 0.358s model: CHAOS-MMA
# 21600 0.566s model: CHAOS80
# 21600 1.73s model: CHAOS
# 21600 0.959s model: MIO_SHA_2C-Primary
# 21600 1.03s model: MIO_SHA_2C-Secondary
# 21600 1.81s model: MIO_SHA_2C
# PT6H pass #10
# 21600 0.184s plain request
# 21600 0.16s plain request (cached)
# 21600 0.169s filter: Flags_B != 255
# 21600 0.223s aux.var.: MLT, QDLat
# 21600 0.203s model: CHAOS-Core
# 21600 0.504s model: CHAOS-Static80
# 21600 1.72s model: CHAOS-Static
# 21600 0.199s model: CHAOS-MMA-Primary
# 21600 0.197s model: CHAOS-MMA-Secondary
# 21600 0.219s model: CHAOS-MMA
# 21600 0.663s model: CHAOS80
# 21600 1.84s model: CHAOS
# 21600 1.03s model: MIO_SHA_2C-Primary
# 21600 0.995s model: MIO_SHA_2C-Secondary
# 21600 1.75s model: MIO_SHA_2C
# PT1H pass #1
# 3600 0.17s plain request
# 3600 0.149s plain request (cached)
# 3600 0.144s filter: Flags_B != 255
# 3600 0.161s aux.var.: MLT, QDLat
# 3600 0.138s model: CHAOS-Core
# 3600 0.192s model: CHAOS-Static80
# 3600 0.382s model: CHAOS-Static
# 3600 0.146s model: CHAOS-MMA-Primary
# 3600 0.188s model: CHAOS-MMA-Secondary
# 3600 0.223s model: CHAOS-MMA
# 3600 0.231s model: CHAOS80
# 3600 0.458s model: CHAOS
# 3600 0.266s model: MIO_SHA_2C-Primary
# 3600 0.279s model: MIO_SHA_2C-Secondary
# 3600 0.401s model: MIO_SHA_2C
# PT1H pass #2
# 3600 0.186s plain request
# 3600 0.147s plain request (cached)
# 3600 0.15s filter: Flags_B != 255
# 3600 0.149s aux.var.: MLT, QDLat
# 3600 0.163s model: CHAOS-Core
# 3600 0.197s model: CHAOS-Static80
# 3600 0.386s model: CHAOS-Static
# 3600 0.152s model: CHAOS-MMA-Primary
# 3600 0.155s model: CHAOS-MMA-Secondary
# 3600 0.159s model: CHAOS-MMA
# 3600 0.218s model: CHAOS80
# 3600 0.464s model: CHAOS
# 3600 0.345s model: MIO_SHA_2C-Primary
# 3600 0.32s model: MIO_SHA_2C-Secondary
# 3600 0.396s model: MIO_SHA_2C
# PT1H pass #3
# 3600 0.131s plain request
# 3600 0.155s plain request (cached)
# 3600 0.134s filter: Flags_B != 255
# 3600 0.159s aux.var.: MLT, QDLat
# 3600 0.166s model: CHAOS-Core
# 3600 0.202s model: CHAOS-Static80
# 3600 0.377s model: CHAOS-Static
# 3600 0.145s model: CHAOS-MMA-Primary
# 3600 0.171s model: CHAOS-MMA-Secondary
# 3600 0.172s model: CHAOS-MMA
# 3600 0.343s model: CHAOS80
# 3600 0.51s model: CHAOS
# 3600 0.281s model: MIO_SHA_2C-Primary
# 3600 0.282s model: MIO_SHA_2C-Secondary
# 3600 0.421s model: MIO_SHA_2C
# PT1H pass #4
# 3600 0.15s plain request
# 3600 0.135s plain request (cached)
# 3600 0.158s filter: Flags_B != 255
# 3600 0.143s aux.var.: MLT, QDLat
# 3600 0.157s model: CHAOS-Core
# 3600 0.203s model: CHAOS-Static80
# 3600 0.399s model: CHAOS-Static
# 3600 0.196s model: CHAOS-MMA-Primary
# 3600 0.212s model: CHAOS-MMA-Secondary
# 3600 0.181s model: CHAOS-MMA
# 3600 0.246s model: CHAOS80
# 3600 0.423s model: CHAOS
# 3600 0.274s model: MIO_SHA_2C-Primary
# 3600 0.27s model: MIO_SHA_2C-Secondary
# 3600 0.414s model: MIO_SHA_2C
# PT1H pass #5
# 3600 0.161s plain request
# 3600 0.129s plain request (cached)
# 3600 0.151s filter: Flags_B != 255
# 3600 0.148s aux.var.: MLT, QDLat
# 3600 0.156s model: CHAOS-Core
# 3600 0.206s model: CHAOS-Static80
# 3600 0.398s model: CHAOS-Static
# 3600 0.162s model: CHAOS-MMA-Primary
# 3600 0.147s model: CHAOS-MMA-Secondary
# 3600 0.193s model: CHAOS-MMA
# 3600 0.248s model: CHAOS80
# 3600 0.558s model: CHAOS
# 3600 0.267s model: MIO_SHA_2C-Primary
# 3600 0.269s model: MIO_SHA_2C-Secondary
# 3600 0.412s model: MIO_SHA_2C
# PT1H pass #6
# 3600 0.229s plain request
# 3600 0.131s plain request (cached)
# 3600 0.147s filter: Flags_B != 255
# 3600 0.146s aux.var.: MLT, QDLat
# 3600 0.151s model: CHAOS-Core
# 3600 0.192s model: CHAOS-Static80
# 3600 0.391s model: CHAOS-Static
# 3600 0.154s model: CHAOS-MMA-Primary
# 3600 0.182s model: CHAOS-MMA-Secondary
# 3600 0.216s model: CHAOS-MMA
# 3600 0.214s model: CHAOS80
# 3600 0.434s model: CHAOS
# 3600 0.275s model: MIO_SHA_2C-Primary
# 3600 0.273s model: MIO_SHA_2C-Secondary
# 3600 0.419s model: MIO_SHA_2C
# PT1H pass #7
# 3600 0.19s plain request
# 3600 0.138s plain request (cached)
# 3600 0.15s filter: Flags_B != 255
# 3600 0.168s aux.var.: MLT, QDLat
# 3600 0.153s model: CHAOS-Core
# 3600 0.2s model: CHAOS-Static80
# 3600 0.393s model: CHAOS-Static
# 3600 0.162s model: CHAOS-MMA-Primary
# 3600 0.213s model: CHAOS-MMA-Secondary
# 3600 0.188s model: CHAOS-MMA
# 3600 0.245s model: CHAOS80
# 3600 0.428s model: CHAOS
# 3600 0.287s model: MIO_SHA_2C-Primary
# 3600 0.284s model: MIO_SHA_2C-Secondary
# 3600 0.396s model: MIO_SHA_2C
# PT1H pass #8
# 3600 0.132s plain request
# 3600 0.146s plain request (cached)
# 3600 0.137s filter: Flags_B != 255
# 3600 0.157s aux.var.: MLT, QDLat
# 3600 0.148s model: CHAOS-Core
# 3600 0.186s model: CHAOS-Static80
# 3600 0.387s model: CHAOS-Static
# 3600 0.21s model: CHAOS-MMA-Primary
# 3600 0.207s model: CHAOS-MMA-Secondary
# 3600 0.162s model: CHAOS-MMA
# 3600 0.208s model: CHAOS80
# 3600 0.41s model: CHAOS
# 3600 0.274s model: MIO_SHA_2C-Primary
# 3600 0.274s model: MIO_SHA_2C-Secondary
# 3600 0.417s model: MIO_SHA_2C
# PT1H pass #9
# 3600 0.155s plain request
# 3600 0.14s plain request (cached)
# 3600 0.143s filter: Flags_B != 255
# 3600 0.169s aux.var.: MLT, QDLat
# 3600 0.146s model: CHAOS-Core
# 3600 0.189s model: CHAOS-Static80
# 3600 0.386s model: CHAOS-Static
# 3600 0.223s model: CHAOS-MMA-Primary
# 3600 0.221s model: CHAOS-MMA-Secondary
# 3600 0.191s model: CHAOS-MMA
# 3600 0.263s model: CHAOS80
# 3600 0.429s model: CHAOS
# 3600 0.294s model: MIO_SHA_2C-Primary
# 3600 0.27s model: MIO_SHA_2C-Secondary
# 3600 0.396s model: MIO_SHA_2C
# PT1H pass #10
# 3600 0.183s plain request
# 3600 0.136s plain request (cached)
# 3600 0.136s filter: Flags_B != 255
# 3600 0.162s aux.var.: MLT, QDLat
# 3600 0.147s model: CHAOS-Core
# 3600 0.204s model: CHAOS-Static80
# 3600 0.38s model: CHAOS-Static
# 3600 0.175s model: CHAOS-MMA-Primary
# 3600 0.186s model: CHAOS-MMA-Secondary
# 3600 0.161s model: CHAOS-MMA
# 3600 0.228s model: CHAOS80
# 3600 0.551s model: CHAOS
# 3600 0.263s model: MIO_SHA_2C-Primary
# 3600 0.272s model: MIO_SHA_2C-Secondary
# 3600 0.415s model: MIO_SHA_2C
# PT5M pass #1
# 300 0.133s plain request
# 300 0.119s plain request (cached)
# 300 0.122s filter: Flags_B != 255
# 300 0.124s aux.var.: MLT, QDLat
# 300 0.119s model: CHAOS-Core
# 300 0.117s model: CHAOS-Static80
# 300 0.162s model: CHAOS-Static
# 300 0.13s model: CHAOS-MMA-Primary
# 300 0.181s model: CHAOS-MMA-Secondary
# 300 0.194s model: CHAOS-MMA
# 300 0.145s model: CHAOS80
# 300 0.197s model: CHAOS
# 300 0.126s model: MIO_SHA_2C-Primary
# 300 0.131s model: MIO_SHA_2C-Secondary
# 300 0.145s model: MIO_SHA_2C
# PT5M pass #2
# 300 0.133s plain request
# 300 0.115s plain request (cached)
# 300 0.117s filter: Flags_B != 255
# 300 0.121s aux.var.: MLT, QDLat
# 300 0.122s model: CHAOS-Core
# 300 0.116s model: CHAOS-Static80
# 300 0.136s model: CHAOS-Static
# 300 0.128s model: CHAOS-MMA-Primary
# 300 0.235s model: CHAOS-MMA-Secondary
# 300 0.142s model: CHAOS-MMA
# 300 0.251s model: CHAOS80
# 300 0.284s model: CHAOS
# 300 0.124s model: MIO_SHA_2C-Primary
# 300 0.132s model: MIO_SHA_2C-Secondary
# 300 0.149s model: MIO_SHA_2C
# PT5M pass #3
# 300 0.198s plain request
# 300 0.12s plain request (cached)
# 300 0.121s filter: Flags_B != 255
# 300 0.119s aux.var.: MLT, QDLat
# 300 0.114s model: CHAOS-Core
# 300 0.127s model: CHAOS-Static80
# 300 0.137s model: CHAOS-Static
# 300 0.131s model: CHAOS-MMA-Primary
# 300 0.128s model: CHAOS-MMA-Secondary
# 300 0.148s model: CHAOS-MMA
# 300 0.151s model: CHAOS80
# 300 0.159s model: CHAOS
# 300 0.162s model: MIO_SHA_2C-Primary
# 300 0.128s model: MIO_SHA_2C-Secondary
# 300 0.145s model: MIO_SHA_2C
# PT5M pass #4
# 300 0.134s plain request
# 300 0.123s plain request (cached)
# 300 0.128s filter: Flags_B != 255
# 300 0.123s aux.var.: MLT, QDLat
# 300 0.126s model: CHAOS-Core
# 300 0.118s model: CHAOS-Static80
# 300 0.154s model: CHAOS-Static
# 300 0.141s model: CHAOS-MMA-Primary
# 300 0.198s model: CHAOS-MMA-Secondary
# 300 0.158s model: CHAOS-MMA
# 300 0.159s model: CHAOS80
# 300 0.238s model: CHAOS
# 300 0.128s model: MIO_SHA_2C-Primary
# 300 0.128s model: MIO_SHA_2C-Secondary
# 300 0.212s model: MIO_SHA_2C
# PT5M pass #5
# 300 0.142s plain request
# 300 0.12s plain request (cached)
# 300 0.119s filter: Flags_B != 255
# 300 0.122s aux.var.: MLT, QDLat
# 300 0.119s model: CHAOS-Core
# 300 0.124s model: CHAOS-Static80
# 300 0.15s model: CHAOS-Static
# 300 0.186s model: CHAOS-MMA-Primary
# 300 0.225s model: CHAOS-MMA-Secondary
# 300 0.14s model: CHAOS-MMA
# 300 0.154s model: CHAOS80
# 300 0.165s model: CHAOS
# 300 0.136s model: MIO_SHA_2C-Primary
# 300 0.131s model: MIO_SHA_2C-Secondary
# 300 0.144s model: MIO_SHA_2C
# PT5M pass #6
# 300 0.13s plain request
# 300 0.11s plain request (cached)
# 300 0.123s filter: Flags_B != 255
# 300 0.123s aux.var.: MLT, QDLat
# 300 0.119s model: CHAOS-Core
# 300 0.124s model: CHAOS-Static80
# 300 0.146s model: CHAOS-Static
# 300 0.188s model: CHAOS-MMA-Primary
# 300 0.144s model: CHAOS-MMA-Secondary
# 300 0.136s model: CHAOS-MMA
# 300 0.141s model: CHAOS80
# 300 0.165s model: CHAOS
# 300 0.131s model: MIO_SHA_2C-Primary
# 300 0.127s model: MIO_SHA_2C-Secondary
# 300 0.262s model: MIO_SHA_2C
# PT5M pass #7
# 300 0.195s plain request
# 300 0.117s plain request (cached)
# 300 0.147s filter: Flags_B != 255
# 300 0.125s aux.var.: MLT, QDLat
# 300 0.121s model: CHAOS-Core
# 300 0.121s model: CHAOS-Static80
# 300 0.135s model: CHAOS-Static
# 300 0.136s model: CHAOS-MMA-Primary
# 300 0.136s model: CHAOS-MMA-Secondary
# 300 0.166s model: CHAOS-MMA
# 300 0.156s model: CHAOS80
# 300 0.168s model: CHAOS
# 300 0.126s model: MIO_SHA_2C-Primary
# 300 0.128s model: MIO_SHA_2C-Secondary
# 300 0.146s model: MIO_SHA_2C
# PT5M pass #8
# 300 0.13s plain request
# 300 0.119s plain request (cached)
# 300 0.119s filter: Flags_B != 255
# 300 0.116s aux.var.: MLT, QDLat
# 300 0.124s model: CHAOS-Core
# 300 0.121s model: CHAOS-Static80
# 300 0.142s model: CHAOS-Static
# 300 0.134s model: CHAOS-MMA-Primary
# 300 0.132s model: CHAOS-MMA-Secondary
# 300 0.157s model: CHAOS-MMA
# 300 0.26s model: CHAOS80
# 300 0.221s model: CHAOS
# 300 0.129s model: MIO_SHA_2C-Primary
# 300 0.135s model: MIO_SHA_2C-Secondary
# 300 0.144s model: MIO_SHA_2C
# PT5M pass #9
# 300 0.122s plain request
# 300 0.114s plain request (cached)
# 300 0.119s filter: Flags_B != 255
# 300 0.124s aux.var.: MLT, QDLat
# 300 0.116s model: CHAOS-Core
# 300 0.121s model: CHAOS-Static80
# 300 0.14s model: CHAOS-Static
# 300 0.128s model: CHAOS-MMA-Primary
# 300 0.196s model: CHAOS-MMA-Secondary
# 300 0.154s model: CHAOS-MMA
# 300 0.255s model: CHAOS80
# 300 0.166s model: CHAOS
# 300 0.19s model: MIO_SHA_2C-Primary
# 300 0.127s model: MIO_SHA_2C-Secondary
# 300 0.15s model: MIO_SHA_2C
# PT5M pass #10
# 300 0.137s plain request
# 300 0.116s plain request (cached)
# 300 0.119s filter: Flags_B != 255
# 300 0.117s aux.var.: MLT, QDLat
# 300 0.129s model: CHAOS-Core
# 300 0.118s model: CHAOS-Static80
# 300 0.14s model: CHAOS-Static
# 300 0.131s model: CHAOS-MMA-Primary
# 300 0.12s model: CHAOS-MMA-Secondary
# 300 0.152s model: CHAOS-MMA
# 300 0.179s model: CHAOS80
# 300 0.158s model: CHAOS
# 300 0.124s model: MIO_SHA_2C-Primary
# 300 0.172s model: MIO_SHA_2C-Secondary
# 300 0.137s model: MIO_SHA_2C
