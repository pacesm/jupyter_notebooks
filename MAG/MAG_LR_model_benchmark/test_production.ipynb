# %% [markdown]
# ## VirES - magnetic model benchmark - production server
#
# Assess perfomance of the VirES magnetic model evaluation and other parameters wrt. the plain data rerival.
# Get per sample times.
#
# See also [VirES Python Client](https://github.com/ESA-VirES/VirES-Python-Client)

# %%
from benchmark import get_random_collection, run_benchmark_set, write_record

SERVER_URL = "https://vires.services"
FILENAME = "results/2022-11-14_production_benchmark.log"

COLLECTIONS = ["SW_OPER_MAGA_LR_1B", "SW_OPER_MAGB_LR_1B", "SW_OPER_MAGC_LR_1B"]

MODELS = [
    "CHAOS-Core",
    "CHAOS-Static80 = 'CHAOS-Static'(max_degree=80)",
    "CHAOS-Static",
    "CHAOS-MMA-Primary",
    "CHAOS-MMA-Secondary",
    "CHAOS-MMA",
    "CHAOS80 = 'CHAOS-Core' + 'CHAOS-Static'(max_degree=80) + 'CHAOS-MMA-Primary' + 'CHAOS-MMA-Secondary'",
    "CHAOS",
    "MIO_SHA_2C-Primary",
    "MIO_SHA_2C-Secondary",
    "MIO_SHA_2C",
]

TEST_CASES = [
    dict(description="plain request"),
    dict(description="plain request (cached)"),
    dict(description="filter: Flags_B != 255", filters=["Flags_B != 255"]),
    dict(description="aux.var.: MLT, QDLat", auxiliaries=["MLT", "QDLat"]),
    *(
        dict(description=f"model: { model.partition('=')[0].strip() }", models=[model])
        for model in MODELS 
    ),
]

N_RUNS = 10

SELECTION_TIMES = [
    "P1D",
    "PT6H",
    "PT1H",
    "PT5M",
]


with open(FILENAME, "a", encoding="utf8") as log_file:
    for selection_time in SELECTION_TIMES:
        for idx in range(N_RUNS):
            print(f"{selection_time} pass #{idx+1}")
            collection = get_random_collection(COLLECTIONS)
            for record in run_benchmark_set(SERVER_URL, collection, selection_time, TEST_CASES):
                write_record(record, log_file)
# Out:
# P1D pass #1
# 86400 0.364s plain request
# 86400 0.231s plain request (cached)
# 86400 0.279s filter: Flags_B != 255
# 86400 0.499s aux.var.: MLT, QDLat
# 86400 5.47s model: CHAOS-Core
# 86400 19.2s model: CHAOS-Static80
# 86400 24.6s model: CHAOS-Static
# 86400 67.9s model: CHAOS-MMA-Primary
# 86400 63.1s model: CHAOS-MMA-Secondary
# 86400 134s model: CHAOS-MMA
# 86400 159s model: CHAOS80
# 86400 155s model: CHAOS
# 86400 18.8s model: MIO_SHA_2C-Primary
# 86400 18.3s model: MIO_SHA_2C-Secondary
# 86400 36.1s model: MIO_SHA_2C
# P1D pass #2
# 86400 0.313s plain request
# 86400 0.287s plain request (cached)
# 86400 0.238s filter: Flags_B != 255
# 86400 0.5s aux.var.: MLT, QDLat
# 86400 5.53s model: CHAOS-Core
# 86400 19s model: CHAOS-Static80
# 86400 24.3s model: CHAOS-Static
# 86400 64.6s model: CHAOS-MMA-Primary
# 86400 68s model: CHAOS-MMA-Secondary
# 86400 120s model: CHAOS-MMA
# 86400 144s model: CHAOS80
# 86400 144s model: CHAOS
# 86400 18.7s model: MIO_SHA_2C-Primary
# 86400 18.4s model: MIO_SHA_2C-Secondary
# 86400 37.2s model: MIO_SHA_2C
# P1D pass #3
# 86400 0.312s plain request
# 86400 0.225s plain request (cached)
# 86400 0.271s filter: Flags_B != 255
# 86400 0.434s aux.var.: MLT, QDLat
# 86400 5.57s model: CHAOS-Core
# 86400 19s model: CHAOS-Static80
# 86400 24.4s model: CHAOS-Static
# 86400 68.1s model: CHAOS-MMA-Primary
# 86400 69.2s model: CHAOS-MMA-Secondary
# 86400 129s model: CHAOS-MMA
# 86400 151s model: CHAOS80
# 86400 155s model: CHAOS
# 86400 18.2s model: MIO_SHA_2C-Primary
# 86400 18.3s model: MIO_SHA_2C-Secondary
# 86400 36.5s model: MIO_SHA_2C
# P1D pass #4
# 86400 0.302s plain request
# 86400 0.238s plain request (cached)
# 86400 0.234s filter: Flags_B != 255
# 86400 0.42s aux.var.: MLT, QDLat
# 86400 5.35s model: CHAOS-Core
# 86400 18.9s model: CHAOS-Static80
# 86400 24.5s model: CHAOS-Static
# 86400 69.3s model: CHAOS-MMA-Primary
# 86400 67.7s model: CHAOS-MMA-Secondary
# 86400 129s model: CHAOS-MMA
# 86400 152s model: CHAOS80
# 86400 162s model: CHAOS
# 86400 18.5s model: MIO_SHA_2C-Primary
# 86400 18.4s model: MIO_SHA_2C-Secondary
# 86400 36.4s model: MIO_SHA_2C
# P1D pass #5
# 86400 0.292s plain request
# 86400 0.277s plain request (cached)
# 86400 0.3s filter: Flags_B != 255
# 86400 0.432s aux.var.: MLT, QDLat
# 86400 5.45s model: CHAOS-Core
# 86400 18.8s model: CHAOS-Static80
# 86400 68.3s model: CHAOS-MMA-Secondary
# 86400 137s model: CHAOS-MMA
# 86400 167s model: CHAOS
# 86400 18.4s model: MIO_SHA_2C-Primary
# 86400 18.2s model: MIO_SHA_2C-Secondary
# 86400 24.3s model: CHAOS-Static
# 86400 65.4s model: CHAOS-MMA-Primary
# 86400 130s model: CHAOS-MMA
# 86400 159s model: CHAOS80
# 86400 154s model: CHAOS
# 86400 18.3s model: MIO_SHA_2C-Primary
# 86400 18.3s model: MIO_SHA_2C-Secondary
# 86400 35.9s model: MIO_SHA_2C
# P1D pass #7
# 86400 0.334s plain request
# 86400 0.325s plain request (cached)
# 86400 0.322s filter: Flags_B != 255
# 86400 0.481s aux.var.: MLT, QDLat
# 86400 5.41s model: CHAOS-Core
# 86400 19s model: CHAOS-Static80
# 86400 24.4s model: CHAOS-Static
# 86400 67.5s model: CHAOS-MMA-Primary
# 86400 63.1s model: CHAOS-MMA-Secondary
# 86400 125s model: CHAOS-MMA
# 86400 150s model: CHAOS80
# 86400 159s model: CHAOS
# 86400 24.3s model: CHAOS-Static
# 86400 66.1s model: CHAOS-MMA-Primary
# 86400 64.2s model: CHAOS-MMA-Secondary
# 86400 125s model: CHAOS-MMA
# 86400 155s model: CHAOS80
# 86400 142s model: CHAOS
# 86400 0.411s model: MIO_SHA_2C-Primary
# 86400 0.351s model: MIO_SHA_2C-Secondary
# 86400 0.348s model: MIO_SHA_2C
# P1D pass #9
# 86400 0.295s plain request
# 86400 0.262s plain request (cached)
# 86400 0.325s filter: Flags_B != 255
# 86400 0.422s aux.var.: MLT, QDLat
# 86400 5.36s model: CHAOS-Core
# 86400 19.1s model: CHAOS-Static80
# 86400 24.1s model: CHAOS-Static
# 86400 60.5s model: CHAOS-MMA-Primary
# 86400 60.9s model: CHAOS-MMA-Secondary
# 86400 123s model: CHAOS-MMA
# 86400 141s model: CHAOS80
# 86400 153s model: CHAOS
# 86400 18.3s model: MIO_SHA_2C-Primary
# 86400 18.3s model: MIO_SHA_2C-Secondary
# 86400 36s model: MIO_SHA_2C
# P1D pass #10
# 86400 0.37s plain request
# 86400 0.332s plain request (cached)
# 86400 0.235s filter: Flags_B != 255
# 86400 0.416s aux.var.: MLT, QDLat
# 86400 5.77s model: CHAOS-Core
# 86400 19.4s model: CHAOS-Static80
# 86400 24.1s model: CHAOS-Static
# 86400 61.7s model: CHAOS-MMA-Primary
# 86400 66.4s model: CHAOS-MMA-Secondary
# 86400 135s model: CHAOS-MMA
# 86400 153s model: CHAOS80
# 86400 165s model: CHAOS
# 86400 18.3s model: MIO_SHA_2C-Primary
# 86400 18.2s model: MIO_SHA_2C-Secondary
# 86400 36.1s model: MIO_SHA_2C
# PT6H pass #1
# 21600 0.295s plain request
# 21600 0.217s plain request (cached)
# 21600 0.254s filter: Flags_B != 255
# 21600 0.311s aux.var.: MLT, QDLat
# 21600 1.56s model: CHAOS-Core
# 21600 4.91s model: CHAOS-Static80
# 21600 6.4s model: CHAOS-Static
# 21600 16.2s model: CHAOS-MMA-Primary
# 21600 16.4s model: CHAOS-MMA-Secondary
# 21600 31.6s model: CHAOS-MMA
# 21600 38.5s model: CHAOS80
# 21600 40.2s model: CHAOS
# 21600 4.79s model: MIO_SHA_2C-Primary
# 21600 4.76s model: MIO_SHA_2C-Secondary
# 21600 9.41s model: MIO_SHA_2C
# PT6H pass #2
# 21600 0.215s plain request
# 21600 0.225s plain request (cached)
# 21600 0.158s filter: Flags_B != 255
# 21600 0.241s aux.var.: MLT, QDLat
# 21600 1.47s model: CHAOS-Core
# 21600 4.89s model: CHAOS-Static80
# 21600 6.22s model: CHAOS-Static
# 21600 17s model: CHAOS-MMA-Primary
# 21600 16.5s model: CHAOS-MMA-Secondary
# 21600 33.5s model: CHAOS-MMA
# 21600 40.6s model: CHAOS80
# 21600 39.1s model: CHAOS
# 21600 4.81s model: MIO_SHA_2C-Primary
# 21600 4.74s model: MIO_SHA_2C-Secondary
# 21600 9.22s model: MIO_SHA_2C
# PT6H pass #3
# 21600 0.296s plain request
# 21600 0.207s plain request (cached)
# 21600 0.245s filter: Flags_B != 255
# 21600 0.233s aux.var.: MLT, QDLat
# 21600 1.57s model: CHAOS-Core
# 21600 5s model: CHAOS-Static80
# 21600 6.31s model: CHAOS-Static
# 21600 16.5s model: CHAOS-MMA-Primary
# 21600 15.2s model: CHAOS-MMA-Secondary
# 21600 29.9s model: CHAOS-MMA
# 21600 37.3s model: CHAOS80
# 21600 40.2s model: CHAOS
# 21600 4.72s model: MIO_SHA_2C-Primary
# 21600 4.69s model: MIO_SHA_2C-Secondary
# 21600 9.3s model: MIO_SHA_2C
# PT6H pass #4
# 21600 0.301s plain request
# 21600 0.19s plain request (cached)
# 21600 0.206s filter: Flags_B != 255
# 21600 0.344s aux.var.: MLT, QDLat
# 21600 1.55s model: CHAOS-Core
# 21600 4.9s model: CHAOS-Static80
# 21600 6.23s model: CHAOS-Static
# 21600 15.6s model: CHAOS-MMA-Primary
# 21600 16.6s model: CHAOS-MMA-Secondary
# 21600 31.9s model: CHAOS-MMA
# 21600 37.7s model: CHAOS80
# 21600 39s model: CHAOS
# 21600 4.73s model: MIO_SHA_2C-Primary
# 21600 4.72s model: MIO_SHA_2C-Secondary
# 21600 9.18s model: MIO_SHA_2C
# PT6H pass #5
# 21600 0.38s plain request
# 21600 0.337s plain request (cached)
# 21600 0.351s filter: Flags_B != 255
# 21600 0.29s aux.var.: MLT, QDLat
# 21600 1.46s model: CHAOS-Core
# 21600 4.86s model: CHAOS-Static80
# 21600 6.22s model: CHAOS-Static
# 21600 15.4s model: CHAOS-MMA-Primary
# 21600 16.9s model: CHAOS-MMA-Secondary
# 21600 29.3s model: CHAOS-MMA
# 21600 37.2s model: CHAOS80
# 21600 35.7s model: CHAOS
# 21600 4.69s model: MIO_SHA_2C-Primary
# 21600 4.79s model: MIO_SHA_2C-Secondary
# 21600 9.27s model: MIO_SHA_2C
# PT6H pass #6
# 21600 0.167s plain request
# 21600 0.168s plain request (cached)
# 21600 0.164s filter: Flags_B != 255
# 21600 0.223s aux.var.: MLT, QDLat
# 21600 1.5s model: CHAOS-Core
# 21600 4.86s model: CHAOS-Static80
# 21600 6.21s model: CHAOS-Static
# 21600 16.1s model: CHAOS-MMA-Primary
# 21600 16.3s model: CHAOS-MMA-Secondary
# 21600 31.6s model: CHAOS-MMA
# 21600 37.2s model: CHAOS80
# 21600 38.6s model: CHAOS
# 21600 4.68s model: MIO_SHA_2C-Primary
# 21600 4.7s model: MIO_SHA_2C-Secondary
# 21600 9.08s model: MIO_SHA_2C
# PT6H pass #7
# 21600 0.273s plain request
# 21600 0.164s plain request (cached)
# 21600 0.228s filter: Flags_B != 255
# 21600 0.217s aux.var.: MLT, QDLat
# 21600 1.64s model: CHAOS-Core
# 21600 4.91s model: CHAOS-Static80
# 21600 6.19s model: CHAOS-Static
# 21600 15.5s model: CHAOS-MMA-Primary
# 21600 16.3s model: CHAOS-MMA-Secondary
# 21600 33.5s model: CHAOS-MMA
# 21600 37.7s model: CHAOS80
# 21600 41.9s model: CHAOS
# 21600 4.71s model: MIO_SHA_2C-Primary
# 21600 4.64s model: MIO_SHA_2C-Secondary
# 21600 9.29s model: MIO_SHA_2C
# PT6H pass #8
# 21600 0.352s plain request
# 21600 0.264s plain request (cached)
# 21600 0.181s filter: Flags_B != 255
# 21600 0.273s aux.var.: MLT, QDLat
# 21600 1.54s model: CHAOS-Core
# 21600 4.87s model: CHAOS-Static80
# 21600 6.24s model: CHAOS-Static
# 21600 16.6s model: CHAOS-MMA-Primary
# 21600 17.6s model: CHAOS-MMA-Secondary
# 21600 34.2s model: CHAOS-MMA
# 21600 38.4s model: CHAOS80
# 21600 41.3s model: CHAOS
# 21600 4.82s model: MIO_SHA_2C-Primary
# 21600 4.75s model: MIO_SHA_2C-Secondary
# 21600 9.22s model: MIO_SHA_2C
# PT6H pass #9
# 21600 0.195s plain request
# 21600 0.163s plain request (cached)
# 21600 0.264s filter: Flags_B != 255
# 21600 0.336s aux.var.: MLT, QDLat
# 21600 1.51s model: CHAOS-Core
# 21600 5.03s model: CHAOS-Static80
# 21600 6.14s model: CHAOS-Static
# 21600 16.4s model: CHAOS-MMA-Primary
# 21600 16.5s model: CHAOS-MMA-Secondary
# 21600 32.9s model: CHAOS-MMA
# 21600 38.5s model: CHAOS80
# 21600 39.8s model: CHAOS
# 21600 4.66s model: MIO_SHA_2C-Primary
# 21600 4.77s model: MIO_SHA_2C-Secondary
# 21600 9.34s model: MIO_SHA_2C
# PT6H pass #10
# 21600 0.216s plain request
# 21600 0.18s plain request (cached)
# 21600 0.192s filter: Flags_B != 255
# 21600 0.353s aux.var.: MLT, QDLat
# 21600 1.44s model: CHAOS-Core
# 21600 4.8s model: CHAOS-Static80
# 21600 6.32s model: CHAOS-Static
# 21600 16.2s model: CHAOS-MMA-Primary
# 21600 16.9s model: CHAOS-MMA-Secondary
# 21600 34.2s model: CHAOS-MMA
# 21600 37.2s model: CHAOS80
# 21600 40.4s model: CHAOS
# 21600 4.89s model: MIO_SHA_2C-Primary
# 21600 4.74s model: MIO_SHA_2C-Secondary
# 21600 9.16s model: MIO_SHA_2C
# PT1H pass #1
# 3600 0.159s plain request
# 3600 0.143s plain request (cached)
# 3600 0.145s filter: Flags_B != 255
# 3600 0.174s aux.var.: MLT, QDLat
# 3600 0.378s model: CHAOS-Core
# 3600 0.94s model: CHAOS-Static80
# 3600 1.15s model: CHAOS-Static
# 3600 2.95s model: CHAOS-MMA-Primary
# 3600 2.98s model: CHAOS-MMA-Secondary
# 3600 5.67s model: CHAOS-MMA
# 3600 6.42s model: CHAOS80
# 3600 7.05s model: CHAOS
# 3600 0.909s model: MIO_SHA_2C-Primary
# 3600 0.909s model: MIO_SHA_2C-Secondary
# 3600 1.76s model: MIO_SHA_2C
# PT1H pass #2
# 3600 0.154s plain request
# 3600 0.141s plain request (cached)
# 3600 0.143s filter: Flags_B != 255
# 3600 0.152s aux.var.: MLT, QDLat
# 3600 0.371s model: CHAOS-Core
# 3600 0.955s model: CHAOS-Static80
# 3600 1.17s model: CHAOS-Static
# 3600 2.93s model: CHAOS-MMA-Primary
# 3600 2.79s model: CHAOS-MMA-Secondary
# 3600 5.31s model: CHAOS-MMA
# 3600 6.44s model: CHAOS80
# 3600 6.63s model: CHAOS
# 3600 0.908s model: MIO_SHA_2C-Primary
# 3600 0.906s model: MIO_SHA_2C-Secondary
# 3600 1.63s model: MIO_SHA_2C
# PT1H pass #3
# 3600 0.152s plain request
# 3600 0.149s plain request (cached)
# 3600 0.139s filter: Flags_B != 255
# 3600 0.156s aux.var.: MLT, QDLat
# 3600 0.378s model: CHAOS-Core
# 3600 0.999s model: CHAOS-Static80
# 3600 1.29s model: CHAOS-Static
# 3600 2.64s model: CHAOS-MMA-Primary
# 3600 3.35s model: CHAOS-MMA-Secondary
# 3600 5.87s model: CHAOS-MMA
# 3600 6.83s model: CHAOS80
# 3600 7.24s model: CHAOS
# 3600 0.93s model: MIO_SHA_2C-Primary
# 3600 0.876s model: MIO_SHA_2C-Secondary
# 3600 1.67s model: MIO_SHA_2C
# PT1H pass #4
# 3600 0.158s plain request
# 3600 0.14s plain request (cached)
# 3600 0.143s filter: Flags_B != 255
# 3600 0.146s aux.var.: MLT, QDLat
# 3600 0.355s model: CHAOS-Core
# 3600 0.94s model: CHAOS-Static80
# 3600 1.22s model: CHAOS-Static
# 3600 3.08s model: CHAOS-MMA-Primary
# 3600 3.03s model: CHAOS-MMA-Secondary
# 3600 5.88s model: CHAOS-MMA
# 3600 6.51s model: CHAOS80
# 3600 6.56s model: CHAOS
# 3600 0.888s model: MIO_SHA_2C-Primary
# 3600 0.895s model: MIO_SHA_2C-Secondary
# 3600 1.67s model: MIO_SHA_2C
# PT1H pass #5
# 3600 0.144s plain request
# 3600 0.156s plain request (cached)
# 3600 0.137s filter: Flags_B != 255
# 3600 0.145s aux.var.: MLT, QDLat
# 3600 0.368s model: CHAOS-Core
# 3600 0.915s model: CHAOS-Static80
# 3600 1.25s model: CHAOS-Static
# 3600 3.05s model: CHAOS-MMA-Primary
# 3600 3.08s model: CHAOS-MMA-Secondary
# 3600 5.84s model: CHAOS-MMA
# 3600 6.69s model: CHAOS80
# 3600 6.89s model: CHAOS
# 3600 0.906s model: MIO_SHA_2C-Primary
# 3600 0.901s model: MIO_SHA_2C-Secondary
# 3600 1.64s model: MIO_SHA_2C
# PT1H pass #6
# 3600 0.156s plain request
# 3600 0.135s plain request (cached)
# 3600 0.142s filter: Flags_B != 255
# 3600 0.143s aux.var.: MLT, QDLat
# 3600 0.35s model: CHAOS-Core
# 3600 0.941s model: CHAOS-Static80
# 3600 1.17s model: CHAOS-Static
# 3600 2.95s model: CHAOS-MMA-Primary
# 3600 2.79s model: CHAOS-MMA-Secondary
# 3600 5.42s model: CHAOS-MMA
# 3600 6.45s model: CHAOS80
# 3600 6.93s model: CHAOS
# 3600 0.952s model: MIO_SHA_2C-Primary
# 3600 0.95s model: MIO_SHA_2C-Secondary
# 3600 1.67s model: MIO_SHA_2C
# PT1H pass #7
# 3600 0.169s plain request
# 3600 0.136s plain request (cached)
# 3600 0.138s filter: Flags_B != 255
# 3600 0.146s aux.var.: MLT, QDLat
# 3600 0.383s model: CHAOS-Core
# 3600 0.906s model: CHAOS-Static80
# 3600 1.17s model: CHAOS-Static
# 3600 2.56s model: CHAOS-MMA-Primary
# 3600 2.67s model: CHAOS-MMA-Secondary
# 3600 5.93s model: CHAOS-MMA
# 3600 6.7s model: CHAOS80
# 3600 6.86s model: CHAOS
# 3600 0.924s model: MIO_SHA_2C-Primary
# 3600 0.89s model: MIO_SHA_2C-Secondary
# 3600 1.63s model: MIO_SHA_2C
# PT1H pass #8
# 3600 0.159s plain request
# 3600 0.136s plain request (cached)
# 3600 0.142s filter: Flags_B != 255
# 3600 0.134s aux.var.: MLT, QDLat
# 3600 0.358s model: CHAOS-Core
# 3600 0.945s model: CHAOS-Static80
# 3600 1.14s model: CHAOS-Static
# 3600 2.83s model: CHAOS-MMA-Primary
# 3600 3.01s model: CHAOS-MMA-Secondary
# 3600 5.7s model: CHAOS-MMA
# 3600 6.43s model: CHAOS80
# 3600 6.65s model: CHAOS
# 3600 0.947s model: MIO_SHA_2C-Primary
# 3600 0.912s model: MIO_SHA_2C-Secondary
# 3600 1.64s model: MIO_SHA_2C
# PT1H pass #9
# 3600 0.145s plain request
# 3600 0.139s plain request (cached)
# 3600 0.136s filter: Flags_B != 255
# 3600 0.16s aux.var.: MLT, QDLat
# 3600 0.345s model: CHAOS-Core
# 3600 0.93s model: CHAOS-Static80
# 3600 1.15s model: CHAOS-Static
# 3600 2.94s model: CHAOS-MMA-Primary
# 3600 2.57s model: CHAOS-MMA-Secondary
# 3600 5.21s model: CHAOS-MMA
# 3600 6.14s model: CHAOS80
# 3600 6.33s model: CHAOS
# 3600 0.935s model: MIO_SHA_2C-Primary
# 3600 0.871s model: MIO_SHA_2C-Secondary
# 3600 1.67s model: MIO_SHA_2C
# PT1H pass #10
# 3600 0.158s plain request
# 3600 0.133s plain request (cached)
# 3600 0.129s filter: Flags_B != 255
# 3600 0.138s aux.var.: MLT, QDLat
# 3600 0.373s model: CHAOS-Core
# 3600 0.935s model: CHAOS-Static80
# 3600 1.12s model: CHAOS-Static
# 3600 2.81s model: CHAOS-MMA-Primary
# 3600 2.56s model: CHAOS-MMA-Secondary
# 3600 5.15s model: CHAOS-MMA
# 3600 6.12s model: CHAOS80
# 3600 6.33s model: CHAOS
# 3600 0.925s model: MIO_SHA_2C-Primary
# 3600 0.883s model: MIO_SHA_2C-Secondary
# 3600 1.65s model: MIO_SHA_2C
# PT5M pass #1
# 300 0.133s plain request
# 300 0.115s plain request (cached)
# 300 0.115s filter: Flags_B != 255
# 300 0.115s aux.var.: MLT, QDLat
# 300 0.139s model: CHAOS-Core
# 300 0.193s model: CHAOS-Static80
# 300 0.203s model: CHAOS-Static
# 300 0.365s model: CHAOS-MMA-Primary
# 300 0.366s model: CHAOS-MMA-Secondary
# 300 0.527s model: CHAOS-MMA
# 300 0.604s model: CHAOS80
# 300 0.639s model: CHAOS
# 300 0.169s model: MIO_SHA_2C-Primary
# 300 0.171s model: MIO_SHA_2C-Secondary
# 300 0.238s model: MIO_SHA_2C
# PT5M pass #2
# 300 0.121s plain request
# 300 0.112s plain request (cached)
# 300 0.126s filter: Flags_B != 255
# 300 0.123s aux.var.: MLT, QDLat
# 300 0.14s model: CHAOS-Core
# 300 0.195s model: CHAOS-Static80
# 300 0.22s model: CHAOS-Static
# 300 0.375s model: CHAOS-MMA-Primary
# 300 0.328s model: CHAOS-MMA-Secondary
# 300 0.511s model: CHAOS-MMA
# 300 0.592s model: CHAOS80
# 300 0.616s model: CHAOS
# 300 0.177s model: MIO_SHA_2C-Primary
# 300 0.182s model: MIO_SHA_2C-Secondary
# 300 0.235s model: MIO_SHA_2C
# PT5M pass #3
# 300 0.122s plain request
# 300 0.107s plain request (cached)
# 300 0.109s filter: Flags_B != 255
# 300 0.109s aux.var.: MLT, QDLat
# 300 0.138s model: CHAOS-Core
# 300 0.172s model: CHAOS-Static80
# 300 0.204s model: CHAOS-Static
# 300 0.417s model: CHAOS-MMA-Primary
# 300 0.39s model: CHAOS-MMA-Secondary
# 300 0.628s model: CHAOS-MMA
# 300 0.618s model: CHAOS80
# 300 0.644s model: CHAOS
# 300 0.171s model: MIO_SHA_2C-Primary
# 300 0.172s model: MIO_SHA_2C-Secondary
# 300 0.26s model: MIO_SHA_2C
# PT5M pass #4
# 300 0.123s plain request
# 300 0.112s plain request (cached)
# 300 0.128s filter: Flags_B != 255
# 300 0.121s aux.var.: MLT, QDLat
# 300 0.136s model: CHAOS-Core
# 300 0.18s model: CHAOS-Static80
# 300 0.214s model: CHAOS-Static
# 300 0.414s model: CHAOS-MMA-Primary
# 300 0.33s model: CHAOS-MMA-Secondary
# 300 0.575s model: CHAOS-MMA
# 300 0.691s model: CHAOS80
# 300 0.642s model: CHAOS
# 300 0.171s model: MIO_SHA_2C-Primary
# 300 0.172s model: MIO_SHA_2C-Secondary
# 300 0.279s model: MIO_SHA_2C
# PT5M pass #5
# 300 0.132s plain request
# 300 0.113s plain request (cached)
# 300 0.115s filter: Flags_B != 255
# 300 0.119s aux.var.: MLT, QDLat
# 300 0.133s model: CHAOS-Core
# 300 0.181s model: CHAOS-Static80
# 300 0.211s model: CHAOS-Static
# 300 0.393s model: CHAOS-MMA-Primary
# 300 0.398s model: CHAOS-MMA-Secondary
# 300 0.593s model: CHAOS-MMA
# 300 0.678s model: CHAOS80
# 300 0.7s model: CHAOS
# 300 0.191s model: MIO_SHA_2C-Primary
# 300 0.182s model: MIO_SHA_2C-Secondary
# 300 0.247s model: MIO_SHA_2C
# PT5M pass #6
# 300 0.136s plain request
# 300 0.119s plain request (cached)
# 300 0.122s filter: Flags_B != 255
# 300 0.12s aux.var.: MLT, QDLat
# 300 0.138s model: CHAOS-Core
# 300 0.187s model: CHAOS-Static80
# 300 0.212s model: CHAOS-Static
# 300 0.342s model: CHAOS-MMA-Primary
# 300 0.349s model: CHAOS-MMA-Secondary
# 300 0.658s model: CHAOS-MMA
# 300 0.754s model: CHAOS80
# 300 0.684s model: CHAOS
# 300 0.252s model: MIO_SHA_2C-Primary
# 300 0.184s model: MIO_SHA_2C-Secondary
# 300 0.244s model: MIO_SHA_2C
# PT5M pass #7
# 300 0.132s plain request
# 300 0.111s plain request (cached)
# 300 0.127s filter: Flags_B != 255
# 300 0.116s aux.var.: MLT, QDLat
# 300 0.131s model: CHAOS-Core
# 300 0.182s model: CHAOS-Static80
# 300 0.209s model: CHAOS-Static
# 300 0.369s model: CHAOS-MMA-Primary
# 300 0.438s model: CHAOS-MMA-Secondary
# 300 0.652s model: CHAOS-MMA
# 300 0.657s model: CHAOS80
# 300 0.832s model: CHAOS
# 300 0.181s model: MIO_SHA_2C-Primary
# 300 0.185s model: MIO_SHA_2C-Secondary
# 300 0.243s model: MIO_SHA_2C
# PT5M pass #8
# 300 0.148s plain request
# 300 0.114s plain request (cached)
# 300 0.117s filter: Flags_B != 255
# 300 0.121s aux.var.: MLT, QDLat
# 300 0.133s model: CHAOS-Core
# 300 0.18s model: CHAOS-Static80
# 300 0.211s model: CHAOS-Static
# 300 0.385s model: CHAOS-MMA-Primary
# 300 0.396s model: CHAOS-MMA-Secondary
# 300 0.576s model: CHAOS-MMA
# 300 0.743s model: CHAOS80
# 300 0.714s model: CHAOS
# 300 0.181s model: MIO_SHA_2C-Primary
# 300 0.183s model: MIO_SHA_2C-Secondary
# 300 0.252s model: MIO_SHA_2C
# PT5M pass #9
# 300 0.132s plain request
# 300 0.12s plain request (cached)
# 300 0.119s filter: Flags_B != 255
# 300 0.122s aux.var.: MLT, QDLat
# 300 0.131s model: CHAOS-Core
# 300 0.186s model: CHAOS-Static80
# 300 0.207s model: CHAOS-Static
# 300 0.374s model: CHAOS-MMA-Primary
# 300 0.384s model: CHAOS-MMA-Secondary
# 300 0.596s model: CHAOS-MMA
# 300 0.672s model: CHAOS80
# 300 0.652s model: CHAOS
# 300 0.184s model: MIO_SHA_2C-Primary
# 300 0.181s model: MIO_SHA_2C-Secondary
# 300 0.252s model: MIO_SHA_2C
# PT5M pass #10
# 300 0.13s plain request
# 300 0.113s plain request (cached)
# 300 0.125s filter: Flags_B != 255
# 300 0.118s aux.var.: MLT, QDLat
# 300 0.133s model: CHAOS-Core
# 300 0.191s model: CHAOS-Static80
# 300 0.211s model: CHAOS-Static
# 300 0.388s model: CHAOS-MMA-Primary
# 300 0.403s model: CHAOS-MMA-Secondary
# 300 0.601s model: CHAOS-MMA
# 300 0.674s model: CHAOS80
# 300 0.684s model: CHAOS
# 300 0.185s model: MIO_SHA_2C-Primary
# 300 0.186s model: MIO_SHA_2C-Secondary
# 300 0.256s model: MIO_SHA_2C
