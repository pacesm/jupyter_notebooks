# %% [markdown]
# ## VirES - magnetic model benchmark - production server (failover)
#
# Assess perfomance of the VirES magnetic model evaluation and other parameters wrt. the plain data rerival.
# Get per sample times.
#
# See also [VirES Python Client](https://github.com/ESA-VirES/VirES-Python-Client)

# %%
from benchmark import get_random_collection, run_benchmark_set, write_record

SERVER_URL = "https://swarm-serv1a.eox.at"
FILENAME = "results/2022-11-14_failover_benchmark.log"

COLLECTIONS = ["SW_OPER_MAGA_LR_1B", "SW_OPER_MAGB_LR_1B", "SW_OPER_MAGC_LR_1B"]

MODELS = [
    "CHAOS-Core",
    "CHAOS-Static80 = 'CHAOS-Static'(max_degree=80)",
    "CHAOS-Static",
    "CHAOS-MMA-Primary",
    "CHAOS-MMA-Secondary",
    "CHAOS-MMA",
    "CHAOS80 = 'CHAOS-Core' + 'CHAOS-Static'(max_degree=80) + 'CHAOS-MMA-Primary' + 'CHAOS-MMA-Secondary'",
    "CHAOS",
    "MIO_SHA_2C-Primary",
    "MIO_SHA_2C-Secondary",
    "MIO_SHA_2C",
]

TEST_CASES = [
    dict(description="plain request"),
    dict(description="plain request (cached)"),
    dict(description="filter: Flags_B != 255", filters=["Flags_B != 255"]),
    dict(description="aux.var.: MLT, QDLat", auxiliaries=["MLT", "QDLat"]),
    *(
        dict(description=f"model: { model.partition('=')[0].strip() }", models=[model])
        for model in MODELS 
    ),
]

N_RUNS = 10

SELECTION_TIMES = [
    "P1D",
    "PT6H",
    "PT1H",
    "PT5M",
]


with open(FILENAME, "a", encoding="utf8") as log_file:
    for selection_time in SELECTION_TIMES:
        for idx in range(N_RUNS):
            print(f"{selection_time} pass #{idx+1}")
            collection = get_random_collection(COLLECTIONS)
            for record in run_benchmark_set(SERVER_URL, collection, selection_time, TEST_CASES):
                write_record(record, log_file)
# Out:
# P1D pass #1
# 86400 0.896s plain request
# 86400 1.49s plain request (cached)
# 86400 0.493s filter: Flags_B != 255
# 86400 1.4s aux.var.: MLT, QDLat
# 86400 4.06s model: CHAOS-Core
# 86400 19.5s model: CHAOS-Static80
# 86400 29.5s model: CHAOS-Static
# 86400 37s model: CHAOS-MMA-Primary
# 86400 38.7s model: CHAOS-MMA-Secondary
# 86400 74.4s model: CHAOS-MMA
# 86400 97.7s model: CHAOS80
# 86400 108s model: CHAOS
# 86400 16.9s model: MIO_SHA_2C-Primary
# 86400 17.2s model: MIO_SHA_2C-Secondary
# 86400 33.6s model: MIO_SHA_2C
# P1D pass #2
# 86400 0.997s plain request
# 86400 0.858s plain request (cached)
# 86400 1.51s filter: Flags_B != 255
# 86400 1.02s aux.var.: MLT, QDLat
# 86400 4.31s model: CHAOS-Core
# 86400 20.7s model: CHAOS-Static80
# 86400 28.5s model: CHAOS-Static
# 86400 36.7s model: CHAOS-MMA-Primary
# 86400 37.9s model: CHAOS-MMA-Secondary
# 86400 74.4s model: CHAOS-MMA
# 86400 97.2s model: CHAOS80
# 86400 107s model: CHAOS
# 86400 17.5s model: MIO_SHA_2C-Primary
# 86400 19s model: MIO_SHA_2C-Secondary
# 86400 33.8s model: MIO_SHA_2C
# P1D pass #3
# 86400 1.53s plain request
# 86400 0.827s plain request (cached)
# 86400 0.474s filter: Flags_B != 255
# 86400 0.72s aux.var.: MLT, QDLat
# 86400 5.34s model: CHAOS-Core
# 86400 19.3s model: CHAOS-Static80
# 86400 28.9s model: CHAOS-Static
# 86400 37.1s model: CHAOS-MMA-Primary
# 86400 38.7s model: CHAOS-MMA-Secondary
# 86400 74.2s model: CHAOS-MMA
# 86400 96.4s model: CHAOS80
# 86400 103s model: CHAOS
# 86400 16.6s model: MIO_SHA_2C-Primary
# 86400 16.5s model: MIO_SHA_2C-Secondary
# 86400 34.7s model: MIO_SHA_2C
# P1D pass #4
# 86400 1.79s plain request
# 86400 0.565s plain request (cached)
# 86400 1.68s filter: Flags_B != 255
# 86400 1.53s aux.var.: MLT, QDLat
# 86400 4.48s model: CHAOS-Core
# 86400 19.7s model: CHAOS-Static80
# 86400 28.1s model: CHAOS-Static
# 86400 38.3s model: CHAOS-MMA-Primary
# 86400 37.4s model: CHAOS-MMA-Secondary
# 86400 77.1s model: CHAOS-MMA
# 86400 98.9s model: CHAOS80
# 86400 105s model: CHAOS
# 86400 16.8s model: MIO_SHA_2C-Primary
# 86400 16.9s model: MIO_SHA_2C-Secondary
# 86400 32.6s model: MIO_SHA_2C
# P1D pass #5
# 86400 1.32s plain request
# 86400 2.48s plain request (cached)
# 86400 0.515s filter: Flags_B != 255
# 86400 0.676s aux.var.: MLT, QDLat
# 86400 5.18s model: CHAOS-Core
# 86400 19.1s model: CHAOS-Static80
# 86400 28.3s model: CHAOS-Static
# 86400 37.4s model: CHAOS-MMA-Primary
# 86400 40.5s model: CHAOS-MMA-Secondary
# 86400 75.4s model: CHAOS-MMA
# 86400 95.7s model: CHAOS80
# 86400 105s model: CHAOS
# 86400 17.2s model: MIO_SHA_2C-Primary
# 86400 17.1s model: MIO_SHA_2C-Secondary
# 86400 32.7s model: MIO_SHA_2C
# P1D pass #6
# 86400 1.06s plain request
# 86400 0.515s plain request (cached)
# 86400 0.512s filter: Flags_B != 255
# 86400 0.914s aux.var.: MLT, QDLat
# 86400 4.31s model: CHAOS-Core
# 86400 19.1s model: CHAOS-Static80
# 86400 28.2s model: CHAOS-Static
# 86400 36.6s model: CHAOS-MMA-Primary
# 86400 37.9s model: CHAOS-MMA-Secondary
# 86400 73.8s model: CHAOS-MMA
# 86400 94.7s model: CHAOS80
# 86400 104s model: CHAOS
# 86400 17.4s model: MIO_SHA_2C-Primary
# 86400 16.6s model: MIO_SHA_2C-Secondary
# 86400 32.8s model: MIO_SHA_2C
# P1D pass #7
# 86400 1.76s plain request
# 86400 0.498s plain request (cached)
# 86400 0.899s filter: Flags_B != 255
# 86400 0.739s aux.var.: MLT, QDLat
# 86400 4.4s model: CHAOS-Core
# 86400 19.2s model: CHAOS-Static80
# 86400 28.4s model: CHAOS-Static
# 86400 37.4s model: CHAOS-MMA-Primary
# 86400 37.1s model: CHAOS-MMA-Secondary
# 86400 73.2s model: CHAOS-MMA
# 86400 96.1s model: CHAOS80
# 86400 105s model: CHAOS
# 86400 17.5s model: MIO_SHA_2C-Primary
# 86400 18.1s model: MIO_SHA_2C-Secondary
# 86400 32.1s model: MIO_SHA_2C
# P1D pass #8
# 86400 3.21s plain request
# 86400 1.79s plain request (cached)
# 86400 0.988s filter: Flags_B != 255
# 86400 0.727s aux.var.: MLT, QDLat
# 86400 4.33s model: CHAOS-Core
# 86400 19s model: CHAOS-Static80
# 86400 28.1s model: CHAOS-Static
# 86400 37.7s model: CHAOS-MMA-Primary
# 86400 38.5s model: CHAOS-MMA-Secondary
# 86400 74.3s model: CHAOS-MMA
# 86400 96.2s model: CHAOS80
# 86400 106s model: CHAOS
# 86400 17s model: MIO_SHA_2C-Primary
# 86400 17s model: MIO_SHA_2C-Secondary
# 86400 33.4s model: MIO_SHA_2C
# P1D pass #9
# 86400 1.36s plain request
# 86400 1s plain request (cached)
# 86400 0.497s filter: Flags_B != 255
# 86400 0.628s aux.var.: MLT, QDLat
# 86400 4.24s model: CHAOS-Core
# 86400 19.7s model: CHAOS-Static80
# 86400 29.7s model: CHAOS-Static
# 86400 37.1s model: CHAOS-MMA-Primary
# 86400 38s model: CHAOS-MMA-Secondary
# 86400 74.1s model: CHAOS-MMA
# 86400 98.2s model: CHAOS80
# 86400 105s model: CHAOS
# 86400 18.2s model: MIO_SHA_2C-Primary
# 86400 16.7s model: MIO_SHA_2C-Secondary
# 86400 32.1s model: MIO_SHA_2C
# P1D pass #10
# 86400 1.06s plain request
# 86400 0.869s plain request (cached)
# 86398 0.665s filter: Flags_B != 255
# 86400 1.14s aux.var.: MLT, QDLat
# 86400 4.3s model: CHAOS-Core
# 86400 20.3s model: CHAOS-Static80
# 86400 28.6s model: CHAOS-Static
# 86400 37.2s model: CHAOS-MMA-Primary
# 86400 37.5s model: CHAOS-MMA-Secondary
# 86400 74.1s model: CHAOS-MMA
# 86400 95.1s model: CHAOS80
# 86400 107s model: CHAOS
# 86400 16.4s model: MIO_SHA_2C-Primary
# 86400 17.1s model: MIO_SHA_2C-Secondary
# 86400 31s model: MIO_SHA_2C
# PT6H pass #1
# 21600 0.962s plain request
# 21600 0.413s plain request (cached)
# 21600 0.608s filter: Flags_B != 255
# 21600 1.14s aux.var.: MLT, QDLat
# 21600 1.35s model: CHAOS-Core
# 21600 5.47s model: CHAOS-Static80
# 21600 7.45s model: CHAOS-Static
# 21600 9.68s model: CHAOS-MMA-Primary
# 21600 9.92s model: CHAOS-MMA-Secondary
# 21600 19.1s model: CHAOS-MMA
# 21600 25s model: CHAOS80
# 21600 27s model: CHAOS
# 21600 4.57s model: MIO_SHA_2C-Primary
# 21600 4.78s model: MIO_SHA_2C-Secondary
# 21600 9.5s model: MIO_SHA_2C
# PT6H pass #2
# 21600 0.786s plain request
# 21600 1s plain request (cached)
# 21600 0.406s filter: Flags_B != 255
# 21600 0.439s aux.var.: MLT, QDLat
# 21600 1.78s model: CHAOS-Core
# 21600 5.75s model: CHAOS-Static80
# 21600 7.34s model: CHAOS-Static
# 21600 9.44s model: CHAOS-MMA-Primary
# 21600 9.95s model: CHAOS-MMA-Secondary
# 21600 19.6s model: CHAOS-MMA
# 21600 24.4s model: CHAOS80
# 21600 27.3s model: CHAOS
# 21600 5.38s model: MIO_SHA_2C-Primary
# 21600 4.52s model: MIO_SHA_2C-Secondary
# 21600 8.56s model: MIO_SHA_2C
# PT6H pass #3
# 21600 0.645s plain request
# 21600 0.391s plain request (cached)
# 21600 1.13s filter: Flags_B != 255
# 21600 0.867s aux.var.: MLT, QDLat
# 21600 1.65s model: CHAOS-Core
# 21600 5.32s model: CHAOS-Static80
# 21600 7.44s model: CHAOS-Static
# 21600 10.1s model: CHAOS-MMA-Primary
# 21600 9.74s model: CHAOS-MMA-Secondary
# 21600 19.2s model: CHAOS-MMA
# 21600 24.2s model: CHAOS80
# 21600 26.7s model: CHAOS
# 21600 5.11s model: MIO_SHA_2C-Primary
# 21600 5.34s model: MIO_SHA_2C-Secondary
# 21600 9.14s model: MIO_SHA_2C
# PT6H pass #4
# 21600 1.21s plain request
# 21600 0.999s plain request (cached)
# 21600 0.918s filter: Flags_B != 255
# 21600 0.639s aux.var.: MLT, QDLat
# 21600 2.06s model: CHAOS-Core
# 21600 5.12s model: CHAOS-Static80
# 21600 7.56s model: CHAOS-Static
# 21600 10.5s model: CHAOS-MMA-Primary
# 21600 9.96s model: CHAOS-MMA-Secondary
# 21600 19.5s model: CHAOS-MMA
# 21600 24.8s model: CHAOS80
# 21600 27.4s model: CHAOS
# 21600 5.51s model: MIO_SHA_2C-Primary
# 21600 4.6s model: MIO_SHA_2C-Secondary
# 21600 9s model: MIO_SHA_2C
# PT6H pass #5
# 21600 0.641s plain request
# 21600 0.395s plain request (cached)
# 21600 1.11s filter: Flags_B != 255
# 21600 0.462s aux.var.: MLT, QDLat
# 21600 1.65s model: CHAOS-Core
# 21600 5.2s model: CHAOS-Static80
# 21600 8.16s model: CHAOS-Static
# 21600 9.68s model: CHAOS-MMA-Primary
# 21600 10.6s model: CHAOS-MMA-Secondary
# 21600 19.2s model: CHAOS-MMA
# 21600 24.9s model: CHAOS80
# 21600 27s model: CHAOS
# 21600 4.47s model: MIO_SHA_2C-Primary
# 21600 5.05s model: MIO_SHA_2C-Secondary
# 21600 8.8s model: MIO_SHA_2C
# PT6H pass #6
# 21600 0.874s plain request
# 21600 0.781s plain request (cached)
# 21600 0.612s filter: Flags_B != 255
# 21600 0.61s aux.var.: MLT, QDLat
# 21600 1.83s model: CHAOS-Core
# 21600 5.64s model: CHAOS-Static80
# 21600 8.31s model: CHAOS-Static
# 21600 10.2s model: CHAOS-MMA-Primary
# 21600 10.1s model: CHAOS-MMA-Secondary
# 21600 19.8s model: CHAOS-MMA
# 21600 25.7s model: CHAOS80
# 21600 26.5s model: CHAOS
# 21600 4.72s model: MIO_SHA_2C-Primary
# 21600 4.49s model: MIO_SHA_2C-Secondary
# 21600 8.55s model: MIO_SHA_2C
# PT6H pass #7
# 21600 1.57s plain request
# 21600 0.919s plain request (cached)
# 21600 0.444s filter: Flags_B != 255
# 21600 1.3s aux.var.: MLT, QDLat
# 21600 2.07s model: CHAOS-Core
# 21600 5.36s model: CHAOS-Static80
# 21600 7.44s model: CHAOS-Static
# 21600 9.84s model: CHAOS-MMA-Primary
# 21600 10.2s model: CHAOS-MMA-Secondary
# 21600 18.9s model: CHAOS-MMA
# 21600 25.1s model: CHAOS80
# 21600 27.5s model: CHAOS
# 21600 4.87s model: MIO_SHA_2C-Primary
# 21600 4.6s model: MIO_SHA_2C-Secondary
# 21600 8.98s model: MIO_SHA_2C
# PT6H pass #8
# 21600 0.684s plain request
# 21600 1.06s plain request (cached)
# 21600 0.916s filter: Flags_B != 255
# 21600 0.795s aux.var.: MLT, QDLat
# 21600 1.92s model: CHAOS-Core
# 21600 6.21s model: CHAOS-Static80
# 21600 7.33s model: CHAOS-Static
# 21600 9.92s model: CHAOS-MMA-Primary
# 21600 9.77s model: CHAOS-MMA-Secondary
# 21600 19.4s model: CHAOS-MMA
# 21600 24.3s model: CHAOS80
# 21600 26.8s model: CHAOS
# 21600 4.47s model: MIO_SHA_2C-Primary
# 21600 4.55s model: MIO_SHA_2C-Secondary
# 21600 8.8s model: MIO_SHA_2C
# PT6H pass #9
# 21600 0.758s plain request
# 21600 0.375s plain request (cached)
# 21600 1.2s filter: Flags_B != 255
# 21600 1.3s aux.var.: MLT, QDLat
# 21600 1.29s model: CHAOS-Core
# 21600 5.8s model: CHAOS-Static80
# 21600 7.61s model: CHAOS-Static
# 21600 9.98s model: CHAOS-MMA-Primary
# 21600 10.8s model: CHAOS-MMA-Secondary
# 21600 19.3s model: CHAOS-MMA
# 21600 24.2s model: CHAOS80
# 21600 27s model: CHAOS
# 21600 4.98s model: MIO_SHA_2C-Primary
# 21600 4.92s model: MIO_SHA_2C-Secondary
# 21600 8.68s model: MIO_SHA_2C
# PT6H pass #10
# 21600 0.669s plain request
# 21600 1.05s plain request (cached)
# 21600 1.14s filter: Flags_B != 255
# 21600 1.24s aux.var.: MLT, QDLat
# 21600 1.7s model: CHAOS-Core
# 21600 5.19s model: CHAOS-Static80
# 21600 8.35s model: CHAOS-Static
# 21600 10.9s model: CHAOS-MMA-Primary
# 21600 9.82s model: CHAOS-MMA-Secondary
# 21600 18.9s model: CHAOS-MMA
# 21600 24.6s model: CHAOS80
# 21600 27.2s model: CHAOS
# 21600 5.33s model: MIO_SHA_2C-Primary
# 21600 5.21s model: MIO_SHA_2C-Secondary
# 21600 8.77s model: MIO_SHA_2C
# PT1H pass #1
# 3600 0.546s plain request
# 3600 0.341s plain request (cached)
# 3600 0.381s filter: Flags_B != 255
# 3600 0.396s aux.var.: MLT, QDLat
# 3600 0.512s model: CHAOS-Core
# 3600 1.19s model: CHAOS-Static80
# 3600 1.55s model: CHAOS-Static
# 3600 1.97s model: CHAOS-MMA-Primary
# 3600 2.1s model: CHAOS-MMA-Secondary
# 3600 3.44s model: CHAOS-MMA
# 3600 4.29s model: CHAOS80
# 3600 4.74s model: CHAOS
# 3600 1.11s model: MIO_SHA_2C-Primary
# 3600 1.06s model: MIO_SHA_2C-Secondary
# 3600 1.73s model: MIO_SHA_2C
# PT1H pass #2
# 3600 0.727s plain request
# 3600 0.338s plain request (cached)
# 3600 0.39s filter: Flags_B != 255
# 3600 0.313s aux.var.: MLT, QDLat
# 3600 0.591s model: CHAOS-Core
# 3600 1.13s model: CHAOS-Static80
# 3600 1.5s model: CHAOS-Static
# 3600 1.91s model: CHAOS-MMA-Primary
# 3600 1.94s model: CHAOS-MMA-Secondary
# 3600 3.41s model: CHAOS-MMA
# 3600 4.41s model: CHAOS80
# 3600 4.8s model: CHAOS
# 3600 1.09s model: MIO_SHA_2C-Primary
# 3600 1.08s model: MIO_SHA_2C-Secondary
# 3600 1.71s model: MIO_SHA_2C
# PT1H pass #3
# 3600 0.619s plain request
# 3600 0.384s plain request (cached)
# 3600 0.361s filter: Flags_B != 255
# 3600 0.393s aux.var.: MLT, QDLat
# 3600 0.617s model: CHAOS-Core
# 3600 1.27s model: CHAOS-Static80
# 3600 1.6s model: CHAOS-Static
# 3600 2.01s model: CHAOS-MMA-Primary
# 3600 2.05s model: CHAOS-MMA-Secondary
# 3600 3.56s model: CHAOS-MMA
# 3600 4.41s model: CHAOS80
# 3600 4.8s model: CHAOS
# 3600 1.01s model: MIO_SHA_2C-Primary
# 3600 1.03s model: MIO_SHA_2C-Secondary
# 3600 1.79s model: MIO_SHA_2C
# PT1H pass #4
# 3600 0.586s plain request
# 3600 0.365s plain request (cached)
# 3600 0.312s filter: Flags_B != 255
# 3600 0.487s aux.var.: MLT, QDLat
# 3600 0.544s model: CHAOS-Core
# 3600 1.12s model: CHAOS-Static80
# 3600 1.6s model: CHAOS-Static
# 3600 2.04s model: CHAOS-MMA-Primary
# 3600 2.03s model: CHAOS-MMA-Secondary
# 3600 3.61s model: CHAOS-MMA
# 3600 4.31s model: CHAOS80
# 3600 4.83s model: CHAOS
# 3600 1.03s model: MIO_SHA_2C-Primary
# 3600 1s model: MIO_SHA_2C-Secondary
# 3600 1.75s model: MIO_SHA_2C
# PT1H pass #5
# 3600 0.629s plain request
# 3600 0.33s plain request (cached)
# 3600 0.305s filter: Flags_B != 255
# 3600 0.308s aux.var.: MLT, QDLat
# 3600 0.578s model: CHAOS-Core
# 3600 1.12s model: CHAOS-Static80
# 3600 1.57s model: CHAOS-Static
# 3600 2.02s model: CHAOS-MMA-Primary
# 3600 1.92s model: CHAOS-MMA-Secondary
# 3600 3.43s model: CHAOS-MMA
# 3600 4.39s model: CHAOS80
# 3600 4.74s model: CHAOS
# 3600 1.02s model: MIO_SHA_2C-Primary
# 3600 1.05s model: MIO_SHA_2C-Secondary
# 3600 1.76s model: MIO_SHA_2C
# PT1H pass #6
# 3600 0.558s plain request
# 3600 0.328s plain request (cached)
# 3600 0.407s filter: Flags_B != 255
# 3600 0.425s aux.var.: MLT, QDLat
# 3600 0.467s model: CHAOS-Core
# 3600 1.28s model: CHAOS-Static80
# 3600 1.68s model: CHAOS-Static
# 3600 1.86s model: CHAOS-MMA-Primary
# 3600 1.95s model: CHAOS-MMA-Secondary
# 3600 3.42s model: CHAOS-MMA
# 3600 4.39s model: CHAOS80
# 3600 4.75s model: CHAOS
# 3600 1.02s model: MIO_SHA_2C-Primary
# 3600 1.05s model: MIO_SHA_2C-Secondary
# 3600 1.76s model: MIO_SHA_2C
# PT1H pass #7
# 3600 0.599s plain request
# 3600 0.328s plain request (cached)
# 3600 0.358s filter: Flags_B != 255
# 3600 0.334s aux.var.: MLT, QDLat
# 3600 0.61s model: CHAOS-Core
# 3600 1.13s model: CHAOS-Static80
# 3600 1.64s model: CHAOS-Static
# 3600 1.93s model: CHAOS-MMA-Primary
# 3600 1.89s model: CHAOS-MMA-Secondary
# 3600 3.61s model: CHAOS-MMA
# 3600 4.47s model: CHAOS80
# 3600 4.73s model: CHAOS
# 3600 1.11s model: MIO_SHA_2C-Primary
# 3600 1.02s model: MIO_SHA_2C-Secondary
# 3600 1.77s model: MIO_SHA_2C
# PT1H pass #8
# 3600 0.745s plain request
# 3600 0.362s plain request (cached)
# 3600 0.447s filter: Flags_B != 255
# 3600 0.46s aux.var.: MLT, QDLat
# 3600 0.58s model: CHAOS-Core
# 3600 1.26s model: CHAOS-Static80
# 3600 1.58s model: CHAOS-Static
# 3600 1.87s model: CHAOS-MMA-Primary
# 3600 1.98s model: CHAOS-MMA-Secondary
# 3600 3.39s model: CHAOS-MMA
# 3600 4.5s model: CHAOS80
# 3600 4.79s model: CHAOS
# 3600 1.06s model: MIO_SHA_2C-Primary
# 3600 1.09s model: MIO_SHA_2C-Secondary
# 3600 1.73s model: MIO_SHA_2C
# PT1H pass #9
# 3600 0.736s plain request
# 3600 0.347s plain request (cached)
# 3600 0.366s filter: Flags_B != 255
# 3600 0.441s aux.var.: MLT, QDLat
# 3600 0.546s model: CHAOS-Core
# 3600 1.16s model: CHAOS-Static80
# 3600 1.59s model: CHAOS-Static
# 3600 1.93s model: CHAOS-MMA-Primary
# 3600 1.94s model: CHAOS-MMA-Secondary
# 3600 3.6s model: CHAOS-MMA
# 3600 4.47s model: CHAOS80
# 3600 4.81s model: CHAOS
# 3600 1.2s model: MIO_SHA_2C-Primary
# 3600 1.07s model: MIO_SHA_2C-Secondary
# 3600 1.81s model: MIO_SHA_2C
# PT1H pass #10
# 3600 0.914s plain request
# 3600 0.322s plain request (cached)
# 3600 0.351s filter: Flags_B != 255
# 3600 0.407s aux.var.: MLT, QDLat
# 3600 0.602s model: CHAOS-Core
# 3600 1.3s model: CHAOS-Static80
# 3600 1.59s model: CHAOS-Static
# 3600 1.96s model: CHAOS-MMA-Primary
# 3600 2.08s model: CHAOS-MMA-Secondary
# 3600 3.37s model: CHAOS-MMA
# 3600 4.5s model: CHAOS80
# 3600 4.82s model: CHAOS
# 3600 1.17s model: MIO_SHA_2C-Primary
# 3600 1.07s model: MIO_SHA_2C-Secondary
# 3600 1.69s model: MIO_SHA_2C
# PT5M pass #1
# 300 0.537s plain request
# 300 0.25s plain request (cached)
# 300 0.326s filter: Flags_B != 255
# 300 0.355s aux.var.: MLT, QDLat
# 300 0.307s model: CHAOS-Core
# 300 0.39s model: CHAOS-Static80
# 300 0.342s model: CHAOS-Static
# 300 0.377s model: CHAOS-MMA-Primary
# 300 0.372s model: CHAOS-MMA-Secondary
# 300 0.579s model: CHAOS-MMA
# 300 0.592s model: CHAOS80
# 300 0.717s model: CHAOS
# 300 0.302s model: MIO_SHA_2C-Primary
# 300 0.304s model: MIO_SHA_2C-Secondary
# 300 0.442s model: MIO_SHA_2C
# PT5M pass #2
# 300 0.443s plain request
# 300 0.245s plain request (cached)
# 300 0.325s filter: Flags_B != 255
# 300 0.317s aux.var.: MLT, QDLat
# 300 0.294s model: CHAOS-Core
# 300 0.384s model: CHAOS-Static80
# 300 0.427s model: CHAOS-Static
# 300 0.412s model: CHAOS-MMA-Primary
# 300 0.466s model: CHAOS-MMA-Secondary
# 300 0.503s model: CHAOS-MMA
# 300 0.591s model: CHAOS80
# 300 0.665s model: CHAOS
# 300 0.415s model: MIO_SHA_2C-Primary
# 300 0.377s model: MIO_SHA_2C-Secondary
# 300 0.424s model: MIO_SHA_2C
# PT5M pass #3
# 300 0.577s plain request
# 300 0.331s plain request (cached)
# 300 0.336s filter: Flags_B != 255
# 300 0.325s aux.var.: MLT, QDLat
# 300 0.257s model: CHAOS-Core
# 300 0.388s model: CHAOS-Static80
# 300 0.385s model: CHAOS-Static
# 300 0.379s model: CHAOS-MMA-Primary
# 300 0.467s model: CHAOS-MMA-Secondary
# 300 0.565s model: CHAOS-MMA
# 300 0.677s model: CHAOS80
# 300 0.691s model: CHAOS
# 300 0.327s model: MIO_SHA_2C-Primary
# 300 0.375s model: MIO_SHA_2C-Secondary
# 300 0.445s model: MIO_SHA_2C
# PT5M pass #4
# 300 0.555s plain request
# 300 0.264s plain request (cached)
# 300 0.25s filter: Flags_B != 255
# 300 0.35s aux.var.: MLT, QDLat
# 300 0.341s model: CHAOS-Core
# 300 0.376s model: CHAOS-Static80
# 300 0.373s model: CHAOS-Static
# 300 0.452s model: CHAOS-MMA-Primary
# 300 0.451s model: CHAOS-MMA-Secondary
# 300 0.547s model: CHAOS-MMA
# 300 0.58s model: CHAOS80
# 300 0.636s model: CHAOS
# 300 0.302s model: MIO_SHA_2C-Primary
# 300 0.393s model: MIO_SHA_2C-Secondary
# 300 0.359s model: MIO_SHA_2C
# PT5M pass #5
# 300 0.436s plain request
# 300 0.329s plain request (cached)
# 300 0.268s filter: Flags_B != 255
# 300 0.244s aux.var.: MLT, QDLat
# 300 0.261s model: CHAOS-Core
# 300 0.304s model: CHAOS-Static80
# 300 0.339s model: CHAOS-Static
# 300 0.377s model: CHAOS-MMA-Primary
# 300 0.396s model: CHAOS-MMA-Secondary
# 300 0.564s model: CHAOS-MMA
# 300 0.665s model: CHAOS80
# 300 0.617s model: CHAOS
# 300 0.305s model: MIO_SHA_2C-Primary
# 300 0.315s model: MIO_SHA_2C-Secondary
# 300 0.366s model: MIO_SHA_2C
# PT5M pass #6
# 300 0.635s plain request
# 300 0.245s plain request (cached)
# 300 0.332s filter: Flags_B != 255
# 300 0.341s aux.var.: MLT, QDLat
# 300 0.263s model: CHAOS-Core
# 300 0.343s model: CHAOS-Static80
# 300 0.338s model: CHAOS-Static
# 300 0.477s model: CHAOS-MMA-Primary
# 300 0.466s model: CHAOS-MMA-Secondary
# 300 0.515s model: CHAOS-MMA
# 300 0.6s model: CHAOS80
# 300 0.617s model: CHAOS
# 300 0.314s model: MIO_SHA_2C-Primary
# 300 0.391s model: MIO_SHA_2C-Secondary
# 300 0.455s model: MIO_SHA_2C
# PT5M pass #7
# 300 0.524s plain request
# 300 0.274s plain request (cached)
# 300 0.248s filter: Flags_B != 255
# 300 0.325s aux.var.: MLT, QDLat
# 300 0.334s model: CHAOS-Core
# 300 0.309s model: CHAOS-Static80
# 300 0.34s model: CHAOS-Static
# 300 0.388s model: CHAOS-MMA-Primary
# 300 0.487s model: CHAOS-MMA-Secondary
# 300 0.529s model: CHAOS-MMA
# 300 0.691s model: CHAOS80
# 300 0.694s model: CHAOS
# 300 0.39s model: MIO_SHA_2C-Primary
# 300 0.298s model: MIO_SHA_2C-Secondary
# 300 0.361s model: MIO_SHA_2C
# PT5M pass #8
# 300 0.431s plain request
# 300 0.29s plain request (cached)
# 300 0.239s filter: Flags_B != 255
# 300 0.252s aux.var.: MLT, QDLat
# 300 0.246s model: CHAOS-Core
# 300 0.301s model: CHAOS-Static80
# 300 0.354s model: CHAOS-Static
# 300 0.423s model: CHAOS-MMA-Primary
# 300 0.395s model: CHAOS-MMA-Secondary
# 300 0.526s model: CHAOS-MMA
# 300 0.66s model: CHAOS80
# 300 0.664s model: CHAOS
# 300 0.396s model: MIO_SHA_2C-Primary
# 300 0.378s model: MIO_SHA_2C-Secondary
# 300 0.347s model: MIO_SHA_2C
# PT5M pass #9
# 300 0.392s plain request
# 300 0.294s plain request (cached)
# 300 0.337s filter: Flags_B != 255
# 300 0.239s aux.var.: MLT, QDLat
# 300 0.325s model: CHAOS-Core
# 300 0.376s model: CHAOS-Static80
# 300 0.373s model: CHAOS-Static
# 300 0.432s model: CHAOS-MMA-Primary
# 300 0.442s model: CHAOS-MMA-Secondary
# 300 0.526s model: CHAOS-MMA
# 300 0.632s model: CHAOS80
# 300 0.64s model: CHAOS
# 300 0.291s model: MIO_SHA_2C-Primary
# 300 0.302s model: MIO_SHA_2C-Secondary
# 300 0.354s model: MIO_SHA_2C
# PT5M pass #10
# 300 0.459s plain request
# 300 0.236s plain request (cached)
# 300 0.262s filter: Flags_B != 255
# 300 0.296s aux.var.: MLT, QDLat
# 300 0.251s model: CHAOS-Core
# 300 0.314s model: CHAOS-Static80
# 300 0.42s model: CHAOS-Static
# 300 0.453s model: CHAOS-MMA-Primary
# 300 0.44s model: CHAOS-MMA-Secondary
# 300 0.588s model: CHAOS-MMA
# 300 0.718s model: CHAOS80
# 300 0.735s model: CHAOS
# 300 0.388s model: MIO_SHA_2C-Primary
# 300 0.299s model: MIO_SHA_2C-Secondary
# 300 0.451s model: MIO_SHA_2C
