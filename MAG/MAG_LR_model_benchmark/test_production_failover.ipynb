# %% [markdown]
# ## VirES - magnetic model benchmark - production server (failover)
#
# Assess perfomance of the VirES magnetic model evaluation and other parameters wrt. the plain data rerival.
# Get per sample times.
#
# See also [VirES Python Client](https://github.com/ESA-VirES/VirES-Python-Client)

# %%
from benchmark import get_random_collection, run_benchmark_set, write_record

SERVER_URL = "https://swarm-serv1a.eox.at"
FILENAME = "results/2022-12-19_failover_benchmark.log"

COLLECTIONS = ["SW_OPER_MAGA_LR_1B", "SW_OPER_MAGB_LR_1B", "SW_OPER_MAGC_LR_1B"]

MODELS = [
    "CHAOS-Core",
    "CHAOS-Static80 = 'CHAOS-Static'(max_degree=80)",
    "CHAOS-Static",
    "CHAOS-MMA-Primary",
    "CHAOS-MMA-Secondary",
    "CHAOS-MMA",
    "CHAOS80 = 'CHAOS-Core' + 'CHAOS-Static'(max_degree=80) + 'CHAOS-MMA-Primary' + 'CHAOS-MMA-Secondary'",
    "CHAOS",
    "MIO_SHA_2C-Primary",
    "MIO_SHA_2C-Secondary",
    "MIO_SHA_2C",
]

TEST_CASES = [
    dict(description="plain request"),
    dict(description="plain request (cached)"),
    dict(description="filter: Flags_B != 255", filters=["Flags_B != 255"]),
    dict(description="aux.var.: MLT, QDLat", auxiliaries=["MLT", "QDLat"]),
    *(
        dict(description=f"model: { model.partition('=')[0].strip() }", models=[model])
        for model in MODELS 
    ),
]

N_RUNS = 10

SELECTION_TIMES = [
    "P1D",
    "PT6H",
    "PT1H",
    "PT5M",
]


with open(FILENAME, "a", encoding="utf8") as log_file:
    for selection_time in SELECTION_TIMES:
        for idx in range(N_RUNS):
            print(f"{selection_time} pass #{idx+1}")
            collection = get_random_collection(COLLECTIONS)
            for record in run_benchmark_set(SERVER_URL, collection, selection_time, TEST_CASES):
                write_record(record, log_file)
# Out:
# P1D pass #1
# 13409 0.678s plain request
# 13409 0.729s plain request (cached)
# 13409 0.827s filter: Flags_B != 255
# 13409 0.661s aux.var.: MLT, QDLat
# 13409 0.499s model: CHAOS-Core
# 13409 0.999s model: CHAOS-Static80
# 13409 1.19s model: CHAOS-Static
# 13409 0.576s model: CHAOS-MMA-Primary
# 13409 1s model: CHAOS-MMA-Secondary
# 13409 0.917s model: CHAOS-MMA
# 13409 0.599s model: CHAOS80
# 13409 1.86s model: CHAOS
# 13409 0.762s model: MIO_SHA_2C-Primary
# 13409 0.508s model: MIO_SHA_2C-Secondary
# 13409 1.02s model: MIO_SHA_2C
# P1D pass #2
# 86400 1.01s plain request
# 86400 0.537s plain request (cached)
# 86297 1.38s filter: Flags_B != 255
# 86400 0.987s aux.var.: MLT, QDLat
# 86400 0.754s model: CHAOS-Core
# 86400 1.73s model: CHAOS-Static80
# 86400 5.95s model: CHAOS-Static
# 86400 0.73s model: CHAOS-MMA-Primary
# 86400 1.03s model: CHAOS-MMA-Secondary
# 86400 2.25s model: CHAOS-MMA
# 86400 2.91s model: CHAOS80
# 86400 6.54s model: CHAOS
# 86400 3.85s model: MIO_SHA_2C-Primary
# 86400 4.93s model: MIO_SHA_2C-Secondary
# 86400 6.69s model: MIO_SHA_2C
# P1D pass #3
# 86400 0.915s plain request
# 86400 0.664s plain request (cached)
# 86398 0.526s filter: Flags_B != 255
# 86400 1.55s aux.var.: MLT, QDLat
# 86400 1.62s model: CHAOS-Core
# 86400 2.08s model: CHAOS-Static80
# 86400 5.56s model: CHAOS-Static
# 86400 0.635s model: CHAOS-MMA-Primary
# 86400 0.606s model: CHAOS-MMA-Secondary
# 86400 1.38s model: CHAOS-MMA
# 86400 1.96s model: CHAOS80
# 86400 5.97s model: CHAOS
# 86400 4.15s model: MIO_SHA_2C-Primary
# 86400 3.36s model: MIO_SHA_2C-Secondary
# 86400 6.44s model: MIO_SHA_2C
# P1D pass #4
# 86400 1.43s plain request
# 86400 0.87s plain request (cached)
# 86400 0.854s filter: Flags_B != 255
# 86400 1.18s aux.var.: MLT, QDLat
# 86400 1.17s model: CHAOS-Core
# 86400 1.5s model: CHAOS-Static80
# 86400 5.62s model: CHAOS-Static
# 86400 1.88s model: CHAOS-MMA-Primary
# 86400 0.716s model: CHAOS-MMA-Secondary
# 86400 0.81s model: CHAOS-MMA
# 86400 1.74s model: CHAOS80
# 86400 5.83s model: CHAOS
# 86400 3.42s model: MIO_SHA_2C-Primary
# 86400 3.52s model: MIO_SHA_2C-Secondary
# 86400 6.1s model: MIO_SHA_2C
# P1D pass #5
# 86400 1.45s plain request
# 86400 1.2s plain request (cached)
# 86400 1.46s filter: Flags_B != 255
# 86400 0.652s aux.var.: MLT, QDLat
# 86400 0.665s model: CHAOS-Core
# 86400 1.49s model: CHAOS-Static80
# 86400 5.97s model: CHAOS-Static
# 86400 0.8s model: CHAOS-MMA-Primary
# 86400 2.25s model: CHAOS-MMA-Secondary
# 86400 1.15s model: CHAOS-MMA
# 86400 4.65s model: CHAOS80
# 86400 6.56s model: CHAOS
# 86400 3.92s model: MIO_SHA_2C-Primary
# 86400 3.79s model: MIO_SHA_2C-Secondary
# 86400 6.53s model: MIO_SHA_2C
# P1D pass #6
# 86400 1.29s plain request
# 86400 0.922s plain request (cached)
# 86400 0.775s filter: Flags_B != 255
# 86400 0.634s aux.var.: MLT, QDLat
# 86400 0.748s model: CHAOS-Core
# 86400 2.07s model: CHAOS-Static80
# 86400 5.65s model: CHAOS-Static
# 86400 2.3s model: CHAOS-MMA-Primary
# 86400 2.04s model: CHAOS-MMA-Secondary
# 86400 3.14s model: CHAOS-MMA
# 86400 3.25s model: CHAOS80
# 86400 6.05s model: CHAOS
# 86400 3.34s model: MIO_SHA_2C-Primary
# 86400 3.92s model: MIO_SHA_2C-Secondary
# 86400 6.89s model: MIO_SHA_2C
# P1D pass #7
# 86400 0.882s plain request
# 86400 0.963s plain request (cached)
# 86397 0.855s filter: Flags_B != 255
# 86400 0.64s aux.var.: MLT, QDLat
# 86400 0.651s model: CHAOS-Core
# 86400 1.69s model: CHAOS-Static80
# 86400 5.95s model: CHAOS-Static
# 86400 2.24s model: CHAOS-MMA-Primary
# 86400 0.837s model: CHAOS-MMA-Secondary
# 86400 1.01s model: CHAOS-MMA
# 86400 2.51s model: CHAOS80
# 86400 6.24s model: CHAOS
# 86400 3.73s model: MIO_SHA_2C-Primary
# 86400 4.17s model: MIO_SHA_2C-Secondary
# 86400 6.48s model: MIO_SHA_2C
# P1D pass #8
# 86400 1.27s plain request
# 86400 1.34s plain request (cached)
# 86400 1.07s filter: Flags_B != 255
# 86400 1.1s aux.var.: MLT, QDLat
# 86400 1.18s model: CHAOS-Core
# 86400 2.84s model: CHAOS-Static80
# 86400 5.54s model: CHAOS-Static
# 86400 2.04s model: CHAOS-MMA-Primary
# 86400 1.12s model: CHAOS-MMA-Secondary
# 86400 3.76s model: CHAOS-MMA
# 86400 2.62s model: CHAOS80
# 86400 6.46s model: CHAOS
# 86400 3.37s model: MIO_SHA_2C-Primary
# 86400 3.78s model: MIO_SHA_2C-Secondary
# 86400 7.32s model: MIO_SHA_2C
# P1D pass #9
# 86400 0.95s plain request
# 86400 2.55s plain request (cached)
# 86400 0.714s filter: Flags_B != 255
# 86400 1.41s aux.var.: MLT, QDLat
# 86400 1.35s model: CHAOS-Core
# 86400 1.93s model: CHAOS-Static80
# 86400 5.9s model: CHAOS-Static
# 86400 0.594s model: CHAOS-MMA-Primary
# 86400 0.976s model: CHAOS-MMA-Secondary
# 86400 0.833s model: CHAOS-MMA
# 86400 2.15s model: CHAOS80
# 86400 6.35s model: CHAOS
# 86400 3.72s model: MIO_SHA_2C-Primary
# 86400 3.38s model: MIO_SHA_2C-Secondary
# 86400 7.1s model: MIO_SHA_2C
# P1D pass #10
# 86400 1.59s plain request
# 86400 0.848s plain request (cached)
# 86400 1.01s filter: Flags_B != 255
# 86400 0.854s aux.var.: MLT, QDLat
# 86400 0.676s model: CHAOS-Core
# 86400 1.55s model: CHAOS-Static80
# 86400 5.59s model: CHAOS-Static
# 86400 0.654s model: CHAOS-MMA-Primary
# 86400 1.55s model: CHAOS-MMA-Secondary
# 86400 1.46s model: CHAOS-MMA
# 86400 3.22s model: CHAOS80
# 86400 6.21s model: CHAOS
# 86400 4.61s model: MIO_SHA_2C-Primary
# 86400 3.49s model: MIO_SHA_2C-Secondary
# 86400 6.33s model: MIO_SHA_2C
# PT6H pass #1
# 21600 0.742s plain request
# 21600 0.475s plain request (cached)
# 21600 0.454s filter: Flags_B != 255
# 21600 0.801s aux.var.: MLT, QDLat
# 21600 0.931s model: CHAOS-Core
# 21600 0.646s model: CHAOS-Static80
# 21600 2.37s model: CHAOS-Static
# 21600 1.25s model: CHAOS-MMA-Primary
# 21600 0.417s model: CHAOS-MMA-Secondary
# 21600 1.41s model: CHAOS-MMA
# 21600 0.741s model: CHAOS80
# 21600 2.55s model: CHAOS
# 21600 1.33s model: MIO_SHA_2C-Primary
# 21600 1.32s model: MIO_SHA_2C-Secondary
# 21600 2.5s model: MIO_SHA_2C
# PT6H pass #2
# 21600 0.564s plain request
# 21600 1.11s plain request (cached)
# 21600 1.02s filter: Flags_B != 255
# 21600 0.524s aux.var.: MLT, QDLat
# 21600 1.42s model: CHAOS-Core
# 21600 1.25s model: CHAOS-Static80
# 21600 2.71s model: CHAOS-Static
# 21600 0.843s model: CHAOS-MMA-Primary
# 21600 1.53s model: CHAOS-MMA-Secondary
# 21600 0.439s model: CHAOS-MMA
# 21600 1.08s model: CHAOS80
# 21600 2.01s model: CHAOS
# 21600 1.09s model: MIO_SHA_2C-Primary
# 21600 1.27s model: MIO_SHA_2C-Secondary
# 21600 2.4s model: MIO_SHA_2C
# PT6H pass #3
# 21600 1.82s plain request
# 21600 0.491s plain request (cached)
# 21600 1.15s filter: Flags_B != 255
# 21600 1.46s aux.var.: MLT, QDLat
# 21600 0.482s model: CHAOS-Core
# 21600 0.667s model: CHAOS-Static80
# 21600 1.67s model: CHAOS-Static
# 21600 0.448s model: CHAOS-MMA-Primary
# 21600 0.47s model: CHAOS-MMA-Secondary
# 21600 1.01s model: CHAOS-MMA
# 21600 0.954s model: CHAOS80
# 21600 1.8s model: CHAOS
# 21600 1.2s model: MIO_SHA_2C-Primary
# 21600 1.54s model: MIO_SHA_2C-Secondary
# 21600 2.25s model: MIO_SHA_2C
# PT6H pass #4
# 21600 1.07s plain request
# 21600 0.522s plain request (cached)
# 21600 0.411s filter: Flags_B != 255
# 21600 1.19s aux.var.: MLT, QDLat
# 21600 0.473s model: CHAOS-Core
# 21600 0.688s model: CHAOS-Static80
# 21600 1.86s model: CHAOS-Static
# 21600 1.09s model: CHAOS-MMA-Primary
# 21600 0.511s model: CHAOS-MMA-Secondary
# 21600 1.08s model: CHAOS-MMA
# 21600 1.75s model: CHAOS80
# 21600 1.77s model: CHAOS
# 21600 1.24s model: MIO_SHA_2C-Primary
# 21600 2.13s model: MIO_SHA_2C-Secondary
# 21600 1.83s model: MIO_SHA_2C
# PT6H pass #5
# 21600 1.68s plain request
# 21600 0.422s plain request (cached)
# 21600 0.42s filter: Flags_B != 255
# 21600 1.39s aux.var.: MLT, QDLat
# 21600 0.842s model: CHAOS-Core
# 21600 1.44s model: CHAOS-Static80
# 21600 2.21s model: CHAOS-Static
# 21600 1.53s model: CHAOS-MMA-Primary
# 21600 1.44s model: CHAOS-MMA-Secondary
# 21600 1.6s model: CHAOS-MMA
# 21600 1.29s model: CHAOS80
# 21600 2.56s model: CHAOS
# 21600 1.75s model: MIO_SHA_2C-Primary
# 21600 1.16s model: MIO_SHA_2C-Secondary
# 21600 2.35s model: MIO_SHA_2C
# PT6H pass #6
# 21600 0.912s plain request
# 21600 0.778s plain request (cached)
# 21600 0.478s filter: Flags_B != 255
# 21600 0.43s aux.var.: MLT, QDLat
# 21600 0.844s model: CHAOS-Core
# 21600 1.64s model: CHAOS-Static80
# 21600 1.97s model: CHAOS-Static
# 21600 1s model: CHAOS-MMA-Primary
# 21600 1.06s model: CHAOS-MMA-Secondary
# 21600 0.564s model: CHAOS-MMA
# 21600 0.819s model: CHAOS80
# 21600 2.02s model: CHAOS
# 21600 1.5s model: MIO_SHA_2C-Primary
# 21600 1.27s model: MIO_SHA_2C-Secondary
# 21600 1.89s model: MIO_SHA_2C
# PT6H pass #7
# 21600 0.946s plain request
# 21600 0.439s plain request (cached)
# 21600 0.542s filter: Flags_B != 255
# 21600 0.882s aux.var.: MLT, QDLat
# 21600 0.902s model: CHAOS-Core
# 21600 0.797s model: CHAOS-Static80
# 21600 2.07s model: CHAOS-Static
# 21600 0.674s model: CHAOS-MMA-Primary
# 21600 0.618s model: CHAOS-MMA-Secondary
# 21600 0.827s model: CHAOS-MMA
# 21600 1.49s model: CHAOS80
# 21600 2.03s model: CHAOS
# 21600 1.23s model: MIO_SHA_2C-Primary
# 21600 1.28s model: MIO_SHA_2C-Secondary
# 21600 2.58s model: MIO_SHA_2C
# PT6H pass #8
# 21600 0.636s plain request
# 21600 0.523s plain request (cached)
# 21600 0.397s filter: Flags_B != 255
# 21600 0.442s aux.var.: MLT, QDLat
# 21600 1.18s model: CHAOS-Core
# 21600 0.851s model: CHAOS-Static80
# 21600 2.1s model: CHAOS-Static
# 21600 0.481s model: CHAOS-MMA-Primary
# 21600 0.729s model: CHAOS-MMA-Secondary
# 21600 1.55s model: CHAOS-MMA
# 21600 0.988s model: CHAOS80
# 21600 2.13s model: CHAOS
# 21600 2.03s model: MIO_SHA_2C-Primary
# 21600 1.39s model: MIO_SHA_2C-Secondary
# 21600 1.94s model: MIO_SHA_2C
# PT6H pass #9
# 21600 1.02s plain request
# 21600 0.661s plain request (cached)
# 21600 0.777s filter: Flags_B != 255
# 21600 0.467s aux.var.: MLT, QDLat
# 21600 0.438s model: CHAOS-Core
# 21600 1.38s model: CHAOS-Static80
# 21600 2.18s model: CHAOS-Static
# 21600 1.28s model: CHAOS-MMA-Primary
# 21600 0.467s model: CHAOS-MMA-Secondary
# 21600 0.549s model: CHAOS-MMA
# 21600 1.43s model: CHAOS80
# 21600 1.85s model: CHAOS
# 21600 1.12s model: MIO_SHA_2C-Primary
# 21600 1.14s model: MIO_SHA_2C-Secondary
# 21600 2.16s model: MIO_SHA_2C
# PT6H pass #10
# 21600 0.951s plain request
# 21600 0.47s plain request (cached)
# 21600 0.561s filter: Flags_B != 255
# 21600 0.728s aux.var.: MLT, QDLat
# 21600 0.445s model: CHAOS-Core
# 21600 0.812s model: CHAOS-Static80
# 21600 1.9s model: CHAOS-Static
# 21600 0.828s model: CHAOS-MMA-Primary
# 21600 0.834s model: CHAOS-MMA-Secondary
# 21600 0.576s model: CHAOS-MMA
# 21600 1.69s model: CHAOS80
# 21600 1.9s model: CHAOS
# 21600 2.09s model: MIO_SHA_2C-Primary
# 21600 2.2s model: MIO_SHA_2C-Secondary
# 21600 2.66s model: MIO_SHA_2C
# PT1H pass #1
# 3600 0.505s plain request
# 3600 0.363s plain request (cached)
# 3600 0.433s filter: Flags_B != 255
# 3600 0.317s aux.var.: MLT, QDLat
# 3600 0.502s model: CHAOS-Core
# 3600 0.43s model: CHAOS-Static80
# 3600 0.606s model: CHAOS-Static
# 3600 0.42s model: CHAOS-MMA-Primary
# 3600 0.518s model: CHAOS-MMA-Secondary
# 3600 0.407s model: CHAOS-MMA
# 3600 0.583s model: CHAOS80
# 3600 0.659s model: CHAOS
# 3600 0.451s model: MIO_SHA_2C-Primary
# 3600 0.537s model: MIO_SHA_2C-Secondary
# 3600 0.626s model: MIO_SHA_2C
# PT1H pass #2
# 3600 0.576s plain request
# 3600 0.346s plain request (cached)
# 3600 0.387s filter: Flags_B != 255
# 3600 0.37s aux.var.: MLT, QDLat
# 3600 0.471s model: CHAOS-Core
# 3600 0.43s model: CHAOS-Static80
# 3600 0.63s model: CHAOS-Static
# 3600 0.408s model: CHAOS-MMA-Primary
# 3600 0.426s model: CHAOS-MMA-Secondary
# 3600 0.397s model: CHAOS-MMA
# 3600 0.664s model: CHAOS80
# 3600 0.686s model: CHAOS
# 3600 0.517s model: MIO_SHA_2C-Primary
# 3600 0.51s model: MIO_SHA_2C-Secondary
# 3600 0.713s model: MIO_SHA_2C
# PT1H pass #3
# 3600 0.527s plain request
# 3600 0.336s plain request (cached)
# 3600 0.329s filter: Flags_B != 255
# 3600 0.333s aux.var.: MLT, QDLat
# 3600 0.455s model: CHAOS-Core
# 3600 0.492s model: CHAOS-Static80
# 3600 0.631s model: CHAOS-Static
# 3600 0.454s model: CHAOS-MMA-Primary
# 3600 0.442s model: CHAOS-MMA-Secondary
# 3600 0.483s model: CHAOS-MMA
# 3600 0.491s model: CHAOS80
# 3600 0.661s model: CHAOS
# 3600 0.6s model: MIO_SHA_2C-Primary
# 3600 0.65s model: MIO_SHA_2C-Secondary
# 3600 0.661s model: MIO_SHA_2C
# PT1H pass #4
# 3600 0.905s plain request
# 3600 0.468s plain request (cached)
# 3600 0.415s filter: Flags_B != 255
# 3600 0.33s aux.var.: MLT, QDLat
# 3600 0.393s model: CHAOS-Core
# 3600 0.407s model: CHAOS-Static80
# 3600 0.644s model: CHAOS-Static
# 3600 0.373s model: CHAOS-MMA-Primary
# 3600 0.455s model: CHAOS-MMA-Secondary
# 3600 0.478s model: CHAOS-MMA
# 3600 0.544s model: CHAOS80
# 3600 0.616s model: CHAOS
# 3600 0.57s model: MIO_SHA_2C-Primary
# 3600 0.468s model: MIO_SHA_2C-Secondary
# 3600 0.706s model: MIO_SHA_2C
# PT1H pass #5
# 3600 0.695s plain request
# 3600 0.336s plain request (cached)
# 3600 0.395s filter: Flags_B != 255
# 3600 0.453s aux.var.: MLT, QDLat
# 3600 0.422s model: CHAOS-Core
# 3600 0.386s model: CHAOS-Static80
# 3600 0.697s model: CHAOS-Static
# 3600 0.445s model: CHAOS-MMA-Primary
# 3600 0.547s model: CHAOS-MMA-Secondary
# 3600 0.498s model: CHAOS-MMA
# 3600 0.46s model: CHAOS80
# 3600 0.733s model: CHAOS
# 3600 0.45s model: MIO_SHA_2C-Primary
# 3600 0.455s model: MIO_SHA_2C-Secondary
# 3600 0.651s model: MIO_SHA_2C
# PT1H pass #6
# 3600 0.709s plain request
# 3600 0.359s plain request (cached)
# 3600 0.365s filter: Flags_B != 255
# 3600 0.36s aux.var.: MLT, QDLat
# 3600 0.341s model: CHAOS-Core
# 3600 0.465s model: CHAOS-Static80
# 3600 0.615s model: CHAOS-Static
# 3600 0.427s model: CHAOS-MMA-Primary
# 3600 0.435s model: CHAOS-MMA-Secondary
# 3600 0.428s model: CHAOS-MMA
# 3600 0.57s model: CHAOS80
# 3600 0.546s model: CHAOS
# 3600 0.536s model: MIO_SHA_2C-Primary
# 3600 0.46s model: MIO_SHA_2C-Secondary
# 3600 0.566s model: MIO_SHA_2C
# PT1H pass #7
# 3600 0.533s plain request
# 3600 0.336s plain request (cached)
# 3600 0.306s filter: Flags_B != 255
# 3600 0.353s aux.var.: MLT, QDLat
# 3600 0.405s model: CHAOS-Core
# 3600 0.434s model: CHAOS-Static80
# 3600 0.545s model: CHAOS-Static
# 3600 0.432s model: CHAOS-MMA-Primary
# 3600 0.435s model: CHAOS-MMA-Secondary
# 3600 0.407s model: CHAOS-MMA
# 3600 0.521s model: CHAOS80
# 3600 0.752s model: CHAOS
# 3600 0.458s model: MIO_SHA_2C-Primary
# 3600 0.539s model: MIO_SHA_2C-Secondary
# 3600 0.537s model: MIO_SHA_2C
# PT1H pass #8
# 3600 0.573s plain request
# 3600 0.337s plain request (cached)
# 3600 0.368s filter: Flags_B != 255
# 3600 0.37s aux.var.: MLT, QDLat
# 3600 0.499s model: CHAOS-Core
# 3600 0.438s model: CHAOS-Static80
# 3600 0.72s model: CHAOS-Static
# 3600 0.515s model: CHAOS-MMA-Primary
# 3600 0.458s model: CHAOS-MMA-Secondary
# 3600 0.36s model: CHAOS-MMA
# 3600 0.578s model: CHAOS80
# 3600 0.725s model: CHAOS
# 3600 0.51s model: MIO_SHA_2C-Primary
# 3600 0.449s model: MIO_SHA_2C-Secondary
# 3600 0.65s model: MIO_SHA_2C
# PT1H pass #9
# 3600 0.605s plain request
# 3600 0.391s plain request (cached)
# 3600 0.302s filter: Flags_B != 255
# 3600 0.47s aux.var.: MLT, QDLat
# 3600 0.34s model: CHAOS-Core
# 3600 0.456s model: CHAOS-Static80
# 3600 0.624s model: CHAOS-Static
# 3600 0.343s model: CHAOS-MMA-Primary
# 3600 0.422s model: CHAOS-MMA-Secondary
# 3600 0.441s model: CHAOS-MMA
# 3600 0.556s model: CHAOS80
# 3600 0.676s model: CHAOS
# 3600 0.534s model: MIO_SHA_2C-Primary
# 3600 0.481s model: MIO_SHA_2C-Secondary
# 3600 0.592s model: MIO_SHA_2C
# PT1H pass #10
# 3600 0.485s plain request
# 3600 0.31s plain request (cached)
# 3600 0.368s filter: Flags_B != 255
# 3600 0.396s aux.var.: MLT, QDLat
# 3600 0.426s model: CHAOS-Core
# 3600 0.488s model: CHAOS-Static80
# 3600 0.534s model: CHAOS-Static
# 3600 0.375s model: CHAOS-MMA-Primary
# 3600 0.36s model: CHAOS-MMA-Secondary
# 3600 0.473s model: CHAOS-MMA
# 3600 0.573s model: CHAOS80
# 3600 0.607s model: CHAOS
# 3600 0.434s model: MIO_SHA_2C-Primary
# 3600 0.545s model: MIO_SHA_2C-Secondary
# 3600 0.613s model: MIO_SHA_2C
# PT5M pass #1
# 300 0.478s plain request
# 300 0.247s plain request (cached)
# 300 0.32s filter: Flags_B != 255
# 300 0.365s aux.var.: MLT, QDLat
# 300 0.311s model: CHAOS-Core
# 300 0.269s model: CHAOS-Static80
# 300 0.259s model: CHAOS-Static
# 300 0.295s model: CHAOS-MMA-Primary
# 300 0.255s model: CHAOS-MMA-Secondary
# 300 0.297s model: CHAOS-MMA
# 300 0.272s model: CHAOS80
# 300 0.308s model: CHAOS
# 300 0.339s model: MIO_SHA_2C-Primary
# 300 0.262s model: MIO_SHA_2C-Secondary
# 300 0.267s model: MIO_SHA_2C
# PT5M pass #2
# 300 0.51s plain request
# 300 0.252s plain request (cached)
# 300 0.252s filter: Flags_B != 255
# 300 0.242s aux.var.: MLT, QDLat
# 300 0.283s model: CHAOS-Core
# 300 0.283s model: CHAOS-Static80
# 300 0.302s model: CHAOS-Static
# 300 0.254s model: CHAOS-MMA-Primary
# 300 0.337s model: CHAOS-MMA-Secondary
# 300 0.36s model: CHAOS-MMA
# 300 0.369s model: CHAOS80
# 300 0.381s model: CHAOS
# 300 0.337s model: MIO_SHA_2C-Primary
# 300 0.258s model: MIO_SHA_2C-Secondary
# 300 0.339s model: MIO_SHA_2C
# PT5M pass #3
# 300 0.418s plain request
# 300 0.275s plain request (cached)
# 300 0.245s filter: Flags_B != 255
# 300 0.246s aux.var.: MLT, QDLat
# 300 0.293s model: CHAOS-Core
# 300 0.334s model: CHAOS-Static80
# 300 0.266s model: CHAOS-Static
# 300 0.333s model: CHAOS-MMA-Primary
# 300 0.333s model: CHAOS-MMA-Secondary
# 300 0.327s model: CHAOS-MMA
# 300 0.346s model: CHAOS80
# 300 0.315s model: CHAOS
# 300 0.295s model: MIO_SHA_2C-Primary
# 300 0.327s model: MIO_SHA_2C-Secondary
# 300 0.296s model: MIO_SHA_2C
# PT5M pass #4
# 300 0.49s plain request
# 300 0.329s plain request (cached)
# 300 0.255s filter: Flags_B != 255
# 300 0.248s aux.var.: MLT, QDLat
# 300 0.331s model: CHAOS-Core
# 300 0.246s model: CHAOS-Static80
# 300 0.263s model: CHAOS-Static
# 300 0.255s model: CHAOS-MMA-Primary
# 300 0.302s model: CHAOS-MMA-Secondary
# 300 0.268s model: CHAOS-MMA
# 300 0.266s model: CHAOS80
# 300 0.388s model: CHAOS
# 300 0.339s model: MIO_SHA_2C-Primary
# 300 0.342s model: MIO_SHA_2C-Secondary
# 300 0.306s model: MIO_SHA_2C
# PT5M pass #5
# 300 0.581s plain request
# 300 0.243s plain request (cached)
# 300 0.29s filter: Flags_B != 255
# 300 0.321s aux.var.: MLT, QDLat
# 300 0.339s model: CHAOS-Core
# 300 0.249s model: CHAOS-Static80
# 300 0.267s model: CHAOS-Static
# 300 0.34s model: CHAOS-MMA-Primary
# 300 0.342s model: CHAOS-MMA-Secondary
# 300 0.263s model: CHAOS-MMA
# 300 0.302s model: CHAOS80
# 300 0.28s model: CHAOS
# 300 0.252s model: MIO_SHA_2C-Primary
# 300 0.343s model: MIO_SHA_2C-Secondary
# 300 0.352s model: MIO_SHA_2C
# PT5M pass #6
# 300 0.688s plain request
# 300 0.24s plain request (cached)
# 300 0.245s filter: Flags_B != 255
# 300 0.245s aux.var.: MLT, QDLat
# 300 0.248s model: CHAOS-Core
# 300 0.334s model: CHAOS-Static80
# 300 0.287s model: CHAOS-Static
# 300 0.249s model: CHAOS-MMA-Primary
# 300 0.341s model: CHAOS-MMA-Secondary
# 300 0.448s model: CHAOS-MMA
# 300 0.269s model: CHAOS80
# 300 0.283s model: CHAOS
# 300 0.35s model: MIO_SHA_2C-Primary
# 300 0.334s model: MIO_SHA_2C-Secondary
# 300 0.294s model: MIO_SHA_2C
# PT5M pass #7
# 300 0.437s plain request
# 300 0.242s plain request (cached)
# 300 0.334s filter: Flags_B != 255
# 300 0.244s aux.var.: MLT, QDLat
# 300 0.335s model: CHAOS-Core
# 300 0.252s model: CHAOS-Static80
# 300 0.265s model: CHAOS-Static
# 300 0.334s model: CHAOS-MMA-Primary
# 300 0.26s model: CHAOS-MMA-Secondary
# 300 0.277s model: CHAOS-MMA
# 300 0.275s model: CHAOS80
# 300 0.359s model: CHAOS
# 300 0.337s model: MIO_SHA_2C-Primary
# 300 0.335s model: MIO_SHA_2C-Secondary
# 300 0.271s model: MIO_SHA_2C
# PT5M pass #8
# 300 0.472s plain request
# 300 0.253s plain request (cached)
# 300 0.245s filter: Flags_B != 255
# 300 0.328s aux.var.: MLT, QDLat
# 300 0.287s model: CHAOS-Core
# 300 0.328s model: CHAOS-Static80
# 300 0.263s model: CHAOS-Static
# 300 0.258s model: CHAOS-MMA-Primary
# 300 0.253s model: CHAOS-MMA-Secondary
# 300 0.341s model: CHAOS-MMA
# 300 0.268s model: CHAOS80
# 300 0.36s model: CHAOS
# 300 0.26s model: MIO_SHA_2C-Primary
# 300 0.251s model: MIO_SHA_2C-Secondary
# 300 0.269s model: MIO_SHA_2C
# PT5M pass #9
# 300 0.412s plain request
# 300 0.245s plain request (cached)
# 300 0.326s filter: Flags_B != 255
# 300 0.247s aux.var.: MLT, QDLat
# 300 0.248s model: CHAOS-Core
# 300 0.299s model: CHAOS-Static80
# 300 0.351s model: CHAOS-Static
# 300 0.319s model: CHAOS-MMA-Primary
# 300 0.307s model: CHAOS-MMA-Secondary
# 300 0.441s model: CHAOS-MMA
# 300 0.279s model: CHAOS80
# 300 0.354s model: CHAOS
# 300 0.336s model: MIO_SHA_2C-Primary
# 300 0.259s model: MIO_SHA_2C-Secondary
# 300 0.27s model: MIO_SHA_2C
# PT5M pass #10
# 300 0.701s plain request
# 300 0.256s plain request (cached)
# 300 0.335s filter: Flags_B != 255
# 300 0.245s aux.var.: MLT, QDLat
# 300 0.324s model: CHAOS-Core
# 300 0.324s model: CHAOS-Static80
# 300 0.342s model: CHAOS-Static
# 300 0.263s model: CHAOS-MMA-Primary
# 300 0.259s model: CHAOS-MMA-Secondary
# 300 0.347s model: CHAOS-MMA
# 300 0.318s model: CHAOS80
# 300 0.301s model: CHAOS
# 300 0.336s model: MIO_SHA_2C-Primary
# 300 0.265s model: MIO_SHA_2C-Secondary
# 300 0.268s model: MIO_SHA_2C
